# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('vgsales_clean.csv', index_col = 0)
data.head()
# Out:
#                                              Title Platform    Publisher  \
# 0                       Starlink: Battle for Atlas       NS      Ubisoft
# 1                                  Super Bomberman     SNES  Hudson Soft
# 2                                       Top Spin 3      PS3    2K Sports
# 3  SpongeBob SquarePants: Battle for Bikini Bottom       XB          THQ
# 4                                               Up      Wii          THQ
#
#             Developer  Total_Shipped  Total_Sales  NA_Sales  EU_Sales  \
# 0     Ubisoft Toronto            NaN     570000.0  350000.0  170000.0
# 1            Produce!            NaN     570000.0       NaN       NaN
# 2     Pam Development            NaN     570000.0   80000.0  370000.0
# 3  Heavy Iron Studios            NaN     570000.0  450000.0  100000.0
# 4                 THQ            NaN     570000.0  220000.0  290000.0
#
#    JP_Sales  Other_Sales     Release Last_Update
# 0       NaN      50000.0  16-10-2018  22-03-2019
# ...

# %%
plt.hist(data['Total_Sales'], bins = 24)
# Out:
# (array([3958., 1714., 1888.,  958.,  871., 1082.,  561.,  481.,  692.,
#          364.,  536.,  354.,  276.,  397.,  189.,  188.,  298.,  199.,
#          284.,  155.,  128.,  205.,  129.,  155.]),
#  array([     0.,  23750.,  47500.,  71250.,  95000., 118750., 142500.,
#         166250., 190000., 213750., 237500., 261250., 285000., 308750.,
#         332500., 356250., 380000., 403750., 427500., 451250., 475000.,
#         498750., 522500., 546250., 570000.]),
#  <a list of 24 Patch objects>)

# %%
data[data['Total_Shipped'].notna()]
# Out:
# Empty DataFrame
# Columns: [Title, Platform, Publisher, Developer, Total_Shipped, Total_Sales, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Release, Last_Update]
# Index: []

# %%
data[data['Total_Sales'] == max(data['Total_Sales'])]
# Out:
#                                               Title Platform  \
# 0                        Starlink: Battle for Atlas       NS
# 1                                   Super Bomberman     SNES
# 2                                        Top Spin 3      PS3
# 3   SpongeBob SquarePants: Battle for Bikini Bottom       XB
# 4                                                Up      Wii
# 5                                      Spider-Man 3     X360
# 6                                  Tony Hawk: Shred      Wii
# 7                                           FIFA 15      Wii
# 8                        SD Gundam G Generation Neo      PS2
# 9                    Resident Evil Outbreak File #2      PS2
# 10                                           NHL 14      PS3
# 11                     The Sims 3: World Adventures       PC
# 12                  Bob the Builder: Can We Fix It?       PS
# 13                                             XIII      PS2
# ...
