# %%
import pandas as pd
import numpy as np
from ast import literal_eval

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 0. Loading Dataset

# %%
rawg_data = pd.read_csv('Files/01_rawg_clean.csv', parse_dates = ['released'])

rawg_data.head()
# Out:
#                          slug                         name   released  \
# 0          grand-theft-auto-v           Grand Theft Auto V 2013-09-17
# 1                    portal-2                     Portal 2 2011-04-18
# 2     the-witcher-3-wild-hunt     The Witcher 3: Wild Hunt 2015-05-18
# 3                 tomb-raider           Tomb Raider (2013) 2013-03-05
# 4  the-elder-scrolls-v-skyrim  The Elder Scrolls V: Skyrim 2011-11-11
#
#    suggestions_count                                          platforms  \
# 0                416  ['PC', 'Xbox Series S/X', 'PlayStation 5', 'Pl...
# 1                582  ['Xbox One', 'PlayStation 3', 'PC', 'Xbox 360'...
# 2                678  ['PC', 'Xbox One', 'Nintendo Switch', 'PlaySta...
# 3                664  ['PC', 'PlayStation 4', 'PlayStation 3', 'Xbox...
# 4                621  ['PC', 'PlayStation 3', 'Xbox 360', 'Nintendo ...
#
#                            genres  \
# 0         ['Action', 'Adventure']
# 1           ['Shooter', 'Puzzle']
# 2  ['Action', 'Adventure', 'RPG']
# 3         ['Action', 'Adventure']
# 4               ['Action', 'RPG']
#
#                                               stores  \
# 0  ['Epic Games', 'PlayStation Store', 'Xbox Stor...
# 1  ['Xbox Store', 'Xbox 360 Store', 'PlayStation ...
# 2  ['GOG', 'Xbox Store', 'Steam', 'PlayStation St...
# 3  ['App Store', 'Google Play', 'PlayStation Stor...
# 4  ['Xbox 360 Store', 'Nintendo Store', 'Steam', ...
#
#                                                 tags   esrb_rating
# 0  ['Singleplayer', 'Steam Achievements', 'Multip...        Mature
# 1  ['Singleplayer', 'Steam Achievements', 'Multip...  Everyone 10+
# 2  ['Singleplayer', 'Atmospheric', 'Full controll...        Mature
# 3  ['Singleplayer', 'Multiplayer', 'Atmospheric',...        Mature
# 4  ['Singleplayer', 'Steam Achievements', 'steam-...        Mature

# %% [markdown]
# # 1. What We Want to Do
#
# We want to unpack values inside the list-like columns, specially `platforms` (we can leave the rest for later, as we can directly do it on the feature engineering process).
#
# The idea is to copy the raw for every platform listed in the column so that it looks like the following:
#
# | slug | name | released | metacritic | suggestions_count | platforms | (...) |
# | ---- | ---- | ---- | ---- | ---- | ---- | ---- |
# | grand-theft-auto-v | Grand Theft Auto V | 2013-09-17 | 97.0 |	416 | PC | (...) |
# | grand-theft-auto-v | Grand Theft Auto V | 2013-09-17 | 97.0 |	416 | Xbox Series S/X | (...) |
# | grand-theft-auto-v | Grand Theft Auto V | 2013-09-17 | 97.0 |	416 | PlayStation 5 | (...) |

# %% [markdown]
# # 2. But first...
#
# CSV files has the problem that saves lists as str, so we have to convert them back to be able to access the data inside them. To do so, we will apply the `literal_eval` function from the `ast` library.
#
# After the first cleaning, there are rows in the list-like columns which are not lists, as the list was a single-element list. We will not apply `literal_eval` on them as they raise an error.

# %%
rawg_data['platforms'] = rawg_data['platforms'].apply(lambda x: literal_eval(x) if pd.notnull(x) and ('[' in x) else x)
rawg_data['genres'] = rawg_data['genres'].apply(lambda x: literal_eval(x) if pd.notnull(x) and ('[' in x) else x)
rawg_data['stores'] = rawg_data['stores'].apply(lambda x: literal_eval(x) if pd.notnull(x) and ('[' in x) else x)
rawg_data['tags'] = rawg_data['tags'].apply(lambda x: literal_eval(x) if pd.notnull(x) and ('[' in x) else x)

# %% [markdown]
# ---
#
# # 3. Checking for NaN values
#
# Now that lists are lists again, let's look at the `NaN` values in this dataset to study them.

# %%
rawg_data.isna().sum()
# Out:
# slug                      2
# name                      2
# released              24608
# suggestions_count         0
# platforms              4074
# genres               114461
# stores                29940
# tags                  61308
# esrb_rating          457779
# dtype: int64

# %% [markdown]
# ### 3.1. Platforms' NaNs
#
#
# On a first glance, we may think that it would be a good idea to remove them in the `platforms` column, as not having a platform means that the game won't be able to be merged into the VCG dataset.
#
# Let's see what kind of games have `NaN` in the `platforms` column.

# %%
rawg_data[rawg_data['platforms'].isna()]
# Out:
#                                 slug                   name   released  \
# 5200            half-life-2-downfall  Half-Life 2: Downfall 2017-04-17
# 6951              minerva-metastasis    MINERVA: Metastasis 2005-09-02
# 15238                      witchfire              Witchfire        NaT
# 19851                     spacewar-2              Spacewar! 1962-01-01
# 21171                  urban-legends          Urban Legends 2015-03-02
# ...                              ...                    ...        ...
# 504637  le-yuan-sheng-huo-hitsuzicun               楽園生活ひつじ村 2014-01-01
# 504645                circle-of-mana         Circle of Mana 2013-03-05
# 504765                       antraxx                Antraxx        NaT
# 504767              the-pyramid-gate       The Pyramid Gate 2014-05-06
# 504911                   miner-willy            Miner Willy        NaT
#
#         suggestions_count platforms             genres   stores  \
# 5200                  311       NaN  [Action, Shooter]    Steam
# 6951                  216       NaN            Shooter    Steam
# 15238                 185       NaN            Shooter      NaN
# 19851                  37       NaN                NaN      NaN
# 21171                 201       NaN             Puzzle  itch.io
# ...                   ...       ...                ...      ...
# 504637                386       NaN                NaN      NaN
# 504645                213       NaN                NaN      NaN
# 504765                359       NaN            Shooter      NaN
# 504767                 42       NaN          Adventure      NaN
# 504911                  0       NaN                NaN      NaN
#
#                                                      tags esrb_rating
# 5200                                       [Mod, destroy]         NaN
# 6951                                                  Mod         NaN
# 15238                                                 NaN         NaN
# 19851                                     [Space, combat]         NaN
# 21171                      [Space, puzzles, gun, Gravity]         NaN
# ...                                                   ...         ...
# 504637                                       Free to Play         NaN
# 504645                     [battle, sword, balance, tree]         NaN
# 504765        [Character Customization, Isometric, Mechs]         NaN
# 504767  [Exploration, Pixel Graphics, Psychedelic, Abs...         NaN
# 504911                                              night         NaN
#
# [4074 rows x 9 columns]

# %% [markdown]
# What we can see here is that when a game has a `NaN` on the `platforms` column, some other list-like columns can also have `NaN` on them.
#
# However, if we look at, for example, the `stores` column more in detail...

# %%
rawg_data[rawg_data['platforms'].isna()]['stores'].value_counts()
# Out:
# itch.io              3273
# PlayStation Store      32
# Google Play             7
# Steam                   4
# Xbox Store              1
# Name: stores, dtype: int64

# %% [markdown]
# We see that there are some portential problems there:
#
# - A game that can be bought in steam should have `PC` on the `Platforms` column.
#
# - The same happens to `Playstation Store` and `Xbox Store`. The problem here is that they are DLCs as we can see below, and they already have their counterpart for consoles on the dataset.

# %%
nan_plat = rawg_data[rawg_data['platforms'].isna()]
ps_store = rawg_data['stores'] == 'PlayStation Store'

nan_plat[ps_store]
# Out:
#                                                      slug  \
# 54624      werewolf-the-apocalypse-earthblood-ps4-and-ps5
# 55002      wrc-9-fia-world-rally-championship-ps4-and-ps5
# 55004                           borderlands-3-ps4-and-ps5
# 69504                            thunderflash-ps4-and-ps5
# 75042                anodyne-2-return-to-dust-ps4-and-ps5
# 78032                         ultragoodness-2-ps4-and-ps5
# 79291                       nioh-2-remastered-ps5-upgrade
# 85784   atelier-ryza-2-lost-legends-and-the-secret-fai...
# 88723                                  ride-4-ps4-and-ps5
# 89754                                 fifa-21-ps4-and-ps5
# 93618                               sparkle-2-ps4-and-ps5
# 100972                       freddy-spaghetti-ps4-and-ps5
# 100973    bridge-constructor-the-walking-dead-ps4-and-ps5
# 104612                              destiny-2-ps4-and-ps5
# 107626                           worms-rumble-ps4-and-ps5
# 107629                 immortals-fenyx-rising-ps4-and-ps5
# 107631                          madden-nfl-21-ps4-and-ps5
# 110087                    concept-destruction-ps4-and-ps5
# 110088                            tesla-force-ps4-and-ps5
# 111476                             poker-club-ps4-and-ps5
# 112830                sackboy-a-big-adventure-ps4-and-ps5
# 112831       marvels-spider-man-miles-morales-ps4-and-ps5
# 112834              mortal-kombat-11-ultimate-ps4-and-ps5
# 112835                                  jydge-ps4-and-ps5
# 115724                      watch-dogs-legion-ps4-and-ps5
# 115725                           undead-horde-ps4-and-ps5
# 115726                           the-pathless-ps4-and-ps5
# 115727                            no-mans-sky-ps4-and-ps5
# 115728                               maneater-ps4-and-ps5
# 115729                           king-oddball-ps4-and-ps5
# 115730                                 dirt-5-ps4-and-ps5
# 115731      assassins-creed-valhalla-ultimate-ps4-and-ps5
#
#                                                      name   released  \
# 54624   Werewolf: The Apocalypse – Earthblood PS4 and PS5 2021-02-04
# 55002      WRC 9 FIA World Rally Championship PS4 and PS5 2020-11-12
# 55004                           Borderlands 3 PS4 and PS5 2020-11-12
# 69504                            Thunderflash PS4 and PS5 2021-02-26
# 75042               Anodyne 2: Return to Dust PS4 and PS5 2021-02-18
# 78032                         UltraGoodness 2 PS4 and PS5 2021-02-09
# 79291                     Nioh 2 Remastered (PS5 Upgrade) 2021-02-05
# 85784   Atelier Ryza 2: Lost Legends and the Secret Fa... 2021-01-26
# 88723                                  RIDE 4 PS4 and PS5 2021-01-21
# 89754                                 FIFA 21 PS4 and PS5 2020-12-02
# 93618                               Sparkle 2 PS4 and PS5 2020-12-21
# 100972                       Freddy Spaghetti PS4 and PS5 2020-12-15
# 100973  Bridge Constructor: The Walking Dead - PS4 and... 2020-12-15
# 104612                              Destiny 2 PS4 and PS5 2020-12-08
# 107626                           Worms Rumble PS4 and PS5 2020-12-01
# 107629                 Immortals Fenyx Rising PS4 and PS5 2020-12-03
# 107631                          Madden NFL 21 PS4 and PS5 2020-12-03
# 110087                    Concept Destruction PS4 and PS5 2020-11-12
# 110088                            Tesla Force PS4 and PS5 2020-11-24
# 111476                             Poker Club PS4 and PS5 2020-11-20
# 112830               Sackboy: A Big Adventure PS4 and PS5 2020-11-12
# 112831     Marvel's Spider-Man: Miles Morales PS4 and PS5 2020-11-12
# 112834              Mortal Kombat 11 Ultimate PS4 and PS5 2020-11-17
# 112835                                  JYDGE PS4 and PS5 2020-11-19
# 115724                     Watch Dogs: Legion PS4 and PS5 2020-11-12
# 115725                           Undead Horde PS4 and PS5 2020-11-12
# 115726                           The Pathless PS4 and PS5 2020-11-12
# 115727                           No Man's Sky PS4 and PS5 2020-11-12
# 115728                               Maneater PS4 and PS5 2020-11-12
# 115729                           King Oddball PS4 and PS5 2020-11-12
# 115730                                 DIRT 5 PS4 and PS5 2020-11-12
# 115731     Assassin's Creed Valhalla Ultimate PS4 and PS5 2020-11-12
#
#         suggestions_count platforms                          genres  \
# 54624                 408       NaN                             NaN
# 55002                 274       NaN                          Racing
# 55004                 275       NaN               [Action, Shooter]
# 69504                 228       NaN                [Action, Arcade]
# 75042                 274       NaN                       Adventure
# 78032                 155       NaN                [Action, Arcade]
# 79291                 206       NaN                          Action
# 85784                 183       NaN                             RPG
# 88723                 275       NaN                          Racing
# 89754                 480       NaN                          Sports
# 93618                 339       NaN                [Action, Puzzle]
# 100972                204       NaN            [Simulation, Casual]
# 100973                196       NaN                          Puzzle
# 104612                688       NaN    [Action, Shooter, Adventure]
# 107626                482       NaN             [Shooter, Strategy]
# 107629                196       NaN                [Adventure, RPG]
# 107631                328       NaN                          Sports
# 110087                250       NaN    [Simulation, Racing, Arcade]
# 110088                291       NaN       [Action, Shooter, Arcade]
# 111476                266       NaN  [Strategy, Simulation, Casual]
# 112830                266       NaN                          Action
# 112831                620       NaN                          Action
# 112834                581       NaN                        Fighting
# 112835                172       NaN               [Action, Shooter]
# 115724                292       NaN             [Action, Adventure]
# 115725                275       NaN        [Action, Adventure, RPG]
# 115726                366       NaN             [Action, Adventure]
# 115727                446       NaN             [Action, Adventure]
# 115728                294       NaN        [Action, Adventure, RPG]
# 115729                110       NaN                          Puzzle
# 115730                359       NaN                             NaN
# 115731                512       NaN                             RPG
#
#                    stores                                               tags  \
# 54624   PlayStation Store  [War, Blood, Destruction, combat, console, pla...
# 55002   PlayStation Store       [Multiplayer, cars, console, japan, offline]
# 55004   PlayStation Store  [Multiplayer, online, friends, console, skill,...
# 69504   PlayStation Store  [Multiplayer, Retro, War, combat, console, wav...
# 75042   PlayStation Store  [friends, explore, console, car, art, offline,...
# 78032   PlayStation Store  [Dark, Blood, battle, fun, console, Traps, bra...
# 79291   PlayStation Store  [Multiplayer, RPG, combat, online, death, Mons...
# 85784   PlayStation Store  [Story, battle, Underwater, island, console, t...
# 88723   PlayStation Store  [Multiplayer, online, race, night, console, la...
# 89754   PlayStation Store  [Multiplayer, online, Football, console, rando...
# 93618   PlayStation Store  [Mystery, Story, Soundtrack, challenge, secret...
# 100972  PlayStation Store  [Physics, Story, Narration, Epic, fun, environ...
# 100973  PlayStation Store  [Physics, fun, fight, console, build, Traps, b...
# 104612  PlayStation Store  [Multiplayer, PvP, Story, combat, online, PvE,...
# 107626  PlayStation Store  [Multiplayer, combat, battle, online, fun, con...
# 107629  PlayStation Store  [puzzles, combat, battle, online, console, swo...
# 107631  PlayStation Store  [Multiplayer, online, history, console, random...
# 110087  PlayStation Store  [Multiplayer, Destruction, battle, Soundtrack,...
# 110088  PlayStation Store  [Multiplayer, battle, character, city, Science...
# 111476  PlayStation Store  [Multiplayer, online, friends, console, room, ...
# 112830  PlayStation Store  [Multiplayer, online, party, Epic, race, fun, ...
# 112831  PlayStation Store                         [console, spider, offline]
# 112834  PlayStation Store  [Multiplayer, Story, battle, character, race, ...
# 112835  PlayStation Store  [Multiplayer, Crime, console, build, offline, ...
# 115724  PlayStation Store  [Multiplayer, city, friends, console, skill, u...
# 115725  PlayStation Store  [War, Loot, console, army, offline, elements, ...
# 115726  PlayStation Store  [puzzles, Epic, island, history, secrets, cons...
# 115727  PlayStation Store  [Multiplayer, Mystery, online, Science, Epic, ...
# 115728  PlayStation Store  [RPG, Fantasy, Controller, Story, Loot, combat...
# 115729  PlayStation Store  [Music, secrets, console, offline, Explosions,...
# 115730  PlayStation Store  [Multiplayer, Story, Epic, race, fun, cars, co...
# 115731  PlayStation Store  [Assassin, character, Epic, console, collectio...
#
#        esrb_rating
# 54624          NaN
# 55002          NaN
# 55004          NaN
# 69504          NaN
# 75042          NaN
# 78032          NaN
# 79291          NaN
# 85784          NaN
# 88723          NaN
# 89754          NaN
# 93618          NaN
# 100972         NaN
# 100973         NaN
# 104612         NaN
# 107626         NaN
# 107629         NaN
# 107631         NaN
# 110087         NaN
# 110088         NaN
# 111476         NaN
# 112830         NaN
# 112831         NaN
# 112834         NaN
# 112835         NaN
# 115724         NaN
# 115725         NaN
# 115726         NaN
# 115727         NaN
# 115728         NaN
# 115729         NaN
# 115730         NaN
# 115731         NaN

# %% [markdown]
# Let's look for some samples from here:

# %%
rawg_data[rawg_data['name'].apply(lambda x: False if type(x) == float or 'Assassin\'s Creed Valhalla' not in x else True)] # NaNs didn't let us filter normally
# Out:
#                                                  slug  \
# 954                          assassins-creed-valhalla
# 115731  assassins-creed-valhalla-ultimate-ps4-and-ps5
#
#                                                   name   released  \
# 954                          Assassin's Creed Valhalla 2020-11-10
# 115731  Assassin's Creed Valhalla Ultimate PS4 and PS5 2020-11-12
#
#         suggestions_count                                          platforms  \
# 954                   449  [PlayStation 5, Xbox One, PC, Xbox Series S/X,...
# 115731                512                                                NaN
#
#                           genres                                       stores  \
# 954     [Action, Adventure, RPG]  [PlayStation Store, Xbox Store, Epic Games]
# 115731                       RPG                            PlayStation Store
#
#                                                      tags esrb_rating
# 954                                    [Fantasy, vikings]      Mature
# 115731  [Assassin, character, Epic, console, collectio...         NaN

# %%
rawg_data[rawg_data['name'].apply(lambda x: False if type(x) == float or 'Borderlands 3' not in x else True)] # NaNs didn't let us filter normally
# Out:
#                                                     slug  \
# 495                                        borderlands-3
# 22322  borderlands-3-moxxis-heist-of-the-handsome-jac...
# 55004                          borderlands-3-ps4-and-ps5
#
#                                                     name   released  \
# 495                                        Borderlands 3 2019-09-13
# 22322  Borderlands 3: Moxxi’s Heist of the Handsome J... 2019-12-19
# 55004                          Borderlands 3 PS4 and PS5 2020-11-12
#
#        suggestions_count                                          platforms  \
# 495                  693  [PC, Xbox Series S/X, PlayStation 5, PlayStati...
# 22322                373                      [Xbox One, PlayStation 4, PC]
# 55004                275                                                NaN
#
#                                   genres  \
# 495    [Action, Shooter, Adventure, RPG]
# 22322       [Action, Shooter, Adventure]
# 55004                  [Action, Shooter]
#
#                                                   stores  \
# 495    [Steam, PlayStation Store, Xbox Store, Epic Ga...
# 22322        [PlayStation Store, Xbox Store, Epic Games]
# 55004                                  PlayStation Store
#
#                                                     tags esrb_rating
# 495    [Singleplayer, Steam Achievements, Multiplayer...      Mature
# 22322                                                NaN      Mature
# 55004  [Multiplayer, online, friends, console, skill,...         NaN

# %% [markdown]
# Let's see if we can gather more insight on the `Steam` department.

# %%
steam = rawg_data['stores'] == 'Steam'

nan_plat[steam]
# Out:
#                        slug                   name   released  \
# 5200   half-life-2-downfall  Half-Life 2: Downfall 2017-04-17
# 6951     minerva-metastasis    MINERVA: Metastasis 2005-09-02
# 32138      endless-dungeons        Endless Dungeon        NaT
# 54543  zenith-the-last-city  Zenith: The Last City        NaT
#
#        suggestions_count platforms                    genres stores  \
# 5200                 311       NaN         [Action, Shooter]  Steam
# 6951                 216       NaN                   Shooter  Steam
# 32138                326       NaN                    Action  Steam
# 54543                260       NaN  [Action, Adventure, RPG]  Steam
#
#                  tags esrb_rating
# 5200   [Mod, destroy]         NaN
# 6951              Mod         NaN
# 32138             NaN         NaN
# 54543             NaN         NaN

# %% [markdown]
# What we see is that **2 of them are MODs (= free content)** and the other 2 are games **not released yet**. Thus, we can remove all these data without losing information. as we do not want mobile-exclusive games and we will not consider itch.io for the moment, as the VGC dataset does not contain data from there, thus no sales data.
#
# ---
#
# ## 3.2. Dropping Rows
#
# Let's then proceed with the removal of rows having the one or more of the next characteristics:
#
# - `platforms` is `NaN`
#
# - Mobile-only games, thus `platforms` only contain whether `Android` or `iOS`
#
# - `stores` has only `itch.io`

# %%
plat_nan = rawg_data.index[rawg_data['platforms'].isna()].tolist()
android = rawg_data.index[rawg_data['platforms']=='Android'].tolist()
ios = rawg_data.index[rawg_data['platforms']=='iOS'].tolist()

plat_to_drop = plat_nan + android + ios

rawg_data = rawg_data.drop(index=plat_to_drop)\
                     .reset_index(drop=True)

rawg_data.shape[0]
# Out:
# 433597

# %%
itchio = rawg_data.index[rawg_data['stores']=='itch.io'].tolist()

rawg_data = rawg_data.drop(index=itchio)\
                     .reset_index(drop=True)

rawg_data.shape[0]
# Out:
# 93978

# %% [markdown]
# We have drastically reduced the dimension of the dataset to almost 20% of the original size.
#
# Let's check how many `NaN` do we have:

# %%
rawg_data.isna().sum()
# Out:
# slug                     0
# name                     0
# released             13657
# suggestions_count        0
# platforms                0
# genres               10237
# stores               27684
# tags                 19606
# esrb_rating          79111
# dtype: int64

# %%
nan_release = rawg_data.index[rawg_data['released'].isna()].tolist()
                   
rawg_data = rawg_data.drop(index = nan_release)\
                     .reset_index(drop=True)

rawg_data
# Out:
#                              slug                         name   released  \
# 0              grand-theft-auto-v           Grand Theft Auto V 2013-09-17
# 1                        portal-2                     Portal 2 2011-04-18
# 2         the-witcher-3-wild-hunt     The Witcher 3: Wild Hunt 2015-05-18
# 3                     tomb-raider           Tomb Raider (2013) 2013-03-05
# 4      the-elder-scrolls-v-skyrim  The Elder Scrolls V: Skyrim 2011-11-11
# ...                           ...                          ...        ...
# 80316                crumble-zone                 Crumble Zone 2012-11-29
# 80317  delta-strike-first-assault  Delta Strike: First Assault 2016-05-31
# 80318          siege-hero-wizards           Siege Hero Wizards 2013-09-05
# 80319                velocispider                 Velocispider 2011-06-01
# 80320            kitten-sanctuary             Kitten Sanctuary 2009-03-13
#
#        suggestions_count                                          platforms  \
# 0                    416  [PC, Xbox Series S/X, PlayStation 5, PlayStati...
# 1                    582  [Xbox One, PlayStation 3, PC, Xbox 360, Linux,...
# 2                    678     [PC, Xbox One, Nintendo Switch, PlayStation 4]
# 3                    664  [PC, PlayStation 4, PlayStation 3, Xbox 360, X...
# 4                    621     [PC, PlayStation 3, Xbox 360, Nintendo Switch]
# ...                  ...                                                ...
# 80316                 95                                     [Android, iOS]
# 80317                356                                            PS Vita
# 80318                193                                     [iOS, Android]
# 80319                 90                                     [iOS, Android]
# 80320                365                                          [iOS, PC]
#
#                          genres  \
# 0           [Action, Adventure]
# 1             [Shooter, Puzzle]
# 2      [Action, Adventure, RPG]
# 3           [Action, Adventure]
# 4                 [Action, RPG]
# ...                         ...
# 80316          [Action, Arcade]
# 80317                    Action
# 80318          [Action, Puzzle]
# 80319  [Action, Arcade, Casual]
# 80320          [Family, Puzzle]
#
#                                                   stores  \
# 0      [Epic Games, PlayStation Store, Xbox Store, Xb...
# 1      [Xbox Store, Xbox 360 Store, PlayStation Store...
# 2            [GOG, Xbox Store, Steam, PlayStation Store]
# 3      [App Store, Google Play, PlayStation Store, St...
# 4      [Xbox 360 Store, Nintendo Store, Steam, PlaySt...
# ...                                                  ...
# 80316                           [App Store, Google Play]
# 80317                                  PlayStation Store
# 80318                           [App Store, Google Play]
# 80319                           [App Store, Google Play]
# 80320                                          App Store
#
#                                                     tags   esrb_rating
# 0      [Singleplayer, Steam Achievements, Multiplayer...        Mature
# 1      [Singleplayer, Steam Achievements, Multiplayer...  Everyone 10+
# 2      [Singleplayer, Atmospheric, Full controller su...        Mature
# 3      [Singleplayer, Multiplayer, Atmospheric, Full ...        Mature
# 4      [Singleplayer, Steam Achievements, steam-tradi...        Mature
# ...                                                  ...           ...
# 80316  [Multiplayer, Space, Colorful, achievements, f...           NaN
# 80317                     [combat, online, Tanks, drone]  Everyone 10+
# 80318         [Physics, Cartoon, hero, Monsters, wizard]  Everyone 10+
# 80319  [Retro, Robots, character, fun, shoot, art, sp...          Teen
# 80320  [Cute, Aliens, achievements, Story, fun, cats,...  Everyone 10+
#
# [80321 rows x 9 columns]

# %% [markdown]
# ---
#
# # 4. Unpacking Columns
#
# Now we would want to unpack the rows to single-platform columns...but how do we accomplish that?
#
# We could do the following:
#
# - Create an auxiliar DataFrame `rawg_aux`
#
# - Iterate over every row with `for idx, row in rawg_data.iterrows()`
#
# - For every platform, append the columns to `rawg_aux`

# %% [markdown]
# \* **Ideally**, we would to do this step with a function being applied to the dataframe.
#
# However, we haven't come up with the idea to how to do it yet.

# %%
rawg_aux = pd.DataFrame(columns = rawg_data.columns)

# %% [markdown]
# ### **Do not execute the code below as it takes a lot to finish executing**

# %%
for idx, row in rawg_data.iterrows():
    
    plats = row['platforms']
    
    if type(plats) != str: # We do not want to do this loop if the game only has one platform (thus, no list-like = string).
        for element in plats:      

            aux = row.copy()
            aux['platforms'] = element

            rawg_aux = rawg_aux.append(aux)
    
    else:
        
        aux = row.copy()
        aux['platforms'] = plats

        rawg_aux = rawg_aux.append(aux)
        
    if idx % 10000 == 0:
        print(idx)


rawg_aux = rawg_aux.rename(columns = {'platforms': 'platform',
                                      'esrb_rating': 'esrb'})

print('Finished!')
# Out:
# 0
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# Finished!

# %%
rawg_data = rawg_aux.reset_index(drop=True)
rawg_data
# Out:
#                       slug                name   released suggestions_count  \
# 0       grand-theft-auto-v  Grand Theft Auto V 2013-09-17               416
# 1       grand-theft-auto-v  Grand Theft Auto V 2013-09-17               416
# 2       grand-theft-auto-v  Grand Theft Auto V 2013-09-17               416
# 3       grand-theft-auto-v  Grand Theft Auto V 2013-09-17               416
# 4       grand-theft-auto-v  Grand Theft Auto V 2013-09-17               416
# ...                    ...                 ...        ...               ...
# 139634  siege-hero-wizards  Siege Hero Wizards 2013-09-05               193
# 139635        velocispider        Velocispider 2011-06-01                90
# 139636        velocispider        Velocispider 2011-06-01                90
# 139637    kitten-sanctuary    Kitten Sanctuary 2009-03-13               365
# 139638    kitten-sanctuary    Kitten Sanctuary 2009-03-13               365
#
#                platform                    genres  \
# 0                    PC       [Action, Adventure]
# 1       Xbox Series S/X       [Action, Adventure]
# 2         PlayStation 5       [Action, Adventure]
# 3         PlayStation 4       [Action, Adventure]
# 4         PlayStation 3       [Action, Adventure]
# ...                 ...                       ...
# 139634          Android          [Action, Puzzle]
# 139635              iOS  [Action, Arcade, Casual]
# 139636          Android  [Action, Arcade, Casual]
# 139637              iOS          [Family, Puzzle]
# 139638               PC          [Family, Puzzle]
#
#                                                    stores  \
# 0       [Epic Games, PlayStation Store, Xbox Store, Xb...
# 1       [Epic Games, PlayStation Store, Xbox Store, Xb...
# 2       [Epic Games, PlayStation Store, Xbox Store, Xb...
# 3       [Epic Games, PlayStation Store, Xbox Store, Xb...
# 4       [Epic Games, PlayStation Store, Xbox Store, Xb...
# ...                                                   ...
# 139634                           [App Store, Google Play]
# 139635                           [App Store, Google Play]
# 139636                           [App Store, Google Play]
# 139637                                          App Store
# 139638                                          App Store
#
#                                                      tags          esrb
# 0       [Singleplayer, Steam Achievements, Multiplayer...        Mature
# 1       [Singleplayer, Steam Achievements, Multiplayer...        Mature
# 2       [Singleplayer, Steam Achievements, Multiplayer...        Mature
# 3       [Singleplayer, Steam Achievements, Multiplayer...        Mature
# 4       [Singleplayer, Steam Achievements, Multiplayer...        Mature
# ...                                                   ...           ...
# 139634         [Physics, Cartoon, hero, Monsters, wizard]  Everyone 10+
# 139635  [Retro, Robots, character, fun, shoot, art, sp...          Teen
# 139636  [Retro, Robots, character, fun, shoot, art, sp...          Teen
# 139637  [Cute, Aliens, achievements, Story, fun, cats,...  Everyone 10+
# 139638  [Cute, Aliens, achievements, Story, fun, cats,...  Everyone 10+
#
# [139639 rows x 9 columns]

# %% [markdown]
# ---
# # 5. Checking For Mobile Games After Unpacking

# %%
sorted(rawg_data['platform'].unique())
# Out:
# ['3DO',
#  'Android',
#  'Apple II',
#  'Atari 2600',
#  'Atari 5200',
#  'Atari 7800',
#  'Atari 8-bit',
#  'Atari Flashback',
#  'Atari Lynx',
#  'Atari ST',
#  'Atari XEGS',
#  'Classic Macintosh',
#  'Commodore / Amiga',
#  'Dreamcast',
#  'Game Boy',
#  'Game Boy Advance',
#  'Game Boy Color',
#  'Game Gear',
#  'GameCube',
#  'Genesis',
#  'Jaguar',
#  'Linux',
#  'NES',
#  'Neo Geo',
#  'Nintendo 3DS',
#  'Nintendo 64',
#  'Nintendo DS',
#  'Nintendo DSi',
#  'Nintendo Switch',
#  'PC',
#  'PS Vita',
#  'PSP',
#  'PlayStation',
#  'PlayStation 2',
#  'PlayStation 3',
#  'PlayStation 4',
#  'PlayStation 5',
#  'SEGA 32X',
#  'SEGA CD',
#  'SEGA Master System',
#  'SEGA Saturn',
#  'SNES',
#  'Web',
#  'Wii',
#  'Wii U',
#  'Xbox',
#  'Xbox 360',
#  'Xbox One',
#  'Xbox Series S/X',
#  'iOS',
#  'macOS']

# %% [markdown]
# We can see that after unpacking the `platforms` column into `platform`, we get `iOS` and `Android` again.
#
# We are going to drop the raws containing those data by getting the indexes and using the `pd.DataFrame.drop()` method.

# %%
ios = rawg_data.index[rawg_data['platform']=='iOS'].tolist()
android = rawg_data.index[rawg_data['platform']=='Android'].tolist()

drop = ios + android

rawg_data = rawg_data.drop(index = drop)\
                     .reset_index(drop=True)

rawg_data
# Out:
#                               slug                         name   released  \
# 0               grand-theft-auto-v           Grand Theft Auto V 2013-09-17
# 1               grand-theft-auto-v           Grand Theft Auto V 2013-09-17
# 2               grand-theft-auto-v           Grand Theft Auto V 2013-09-17
# 3               grand-theft-auto-v           Grand Theft Auto V 2013-09-17
# 4               grand-theft-auto-v           Grand Theft Auto V 2013-09-17
# ...                            ...                          ...        ...
# 121974        docs-for-playstation         Docs for PlayStation 2016-05-18
# 121975        docs-for-playstation         Docs for PlayStation 2016-05-18
# 121976                  bee-leader                   Bee Leader 2012-05-24
# 121977  delta-strike-first-assault  Delta Strike: First Assault 2016-05-31
# 121978            kitten-sanctuary             Kitten Sanctuary 2009-03-13
#
#        suggestions_count         platform                    genres  \
# 0                    416               PC       [Action, Adventure]
# 1                    416  Xbox Series S/X       [Action, Adventure]
# 2                    416    PlayStation 5       [Action, Adventure]
# 3                    416    PlayStation 4       [Action, Adventure]
# 4                    416    PlayStation 3       [Action, Adventure]
# ...                  ...              ...                       ...
# 121974                 0    PlayStation 3                       NaN
# 121975                 0    PlayStation 4                       NaN
# 121976                45            macOS  [Action, Arcade, Casual]
# 121977               356          PS Vita                    Action
# 121978               365               PC          [Family, Puzzle]
#
#                                                    stores  \
# 0       [Epic Games, PlayStation Store, Xbox Store, Xb...
# 1       [Epic Games, PlayStation Store, Xbox Store, Xb...
# 2       [Epic Games, PlayStation Store, Xbox Store, Xb...
# 3       [Epic Games, PlayStation Store, Xbox Store, Xb...
# 4       [Epic Games, PlayStation Store, Xbox Store, Xb...
# ...                                                   ...
# 121974                                  PlayStation Store
# 121975                                  PlayStation Store
# 121976                                          App Store
# 121977                                  PlayStation Store
# 121978                                          App Store
#
#                                                      tags          esrb
# 0       [Singleplayer, Steam Achievements, Multiplayer...        Mature
# 1       [Singleplayer, Steam Achievements, Multiplayer...        Mature
# 2       [Singleplayer, Steam Achievements, Multiplayer...        Mature
# 3       [Singleplayer, Steam Achievements, Multiplayer...        Mature
# 4       [Singleplayer, Steam Achievements, Multiplayer...        Mature
# ...                                                   ...           ...
# 121974                      [Music, online, console, art]           NaN
# 121975                      [Music, online, console, art]           NaN
# 121976  [Cute, Physics, achievements, Music, city, Fli...           NaN
# 121977                     [combat, online, Tanks, drone]  Everyone 10+
# 121978  [Cute, Aliens, achievements, Story, fun, cats,...  Everyone 10+
#
# [121979 rows x 9 columns]

# %% [markdown]
# # 6. Getting URLS Scrape Metacritic's Web Site
#
# ## 6.1. Listing the platforms available in Metacritic into a dictionary
#
# Remember the metacritic page for a game has the next format:
#
# **https://www.metacritic.com/game/PLATFORM/SLUG**
#
# But not every platform in this dataset is available, as this page did not exist back then.
#
# We will list the platforms available in Metacritic inside a dictionary, using the `Platform` column counterpart as the key value:
# `RAWG-platform: Metacritic-platform`

# %%
platforms_metacritic = {
    
    # Sony
    
    "PlayStation 5": "playstation-5",
    "PlayStation 4": "playstation-4",
    "PlayStation 3": "ps3",
    "PlayStation 2": "ps2",
    "PlayStation": "ps",
    "PS Vita": "vita",
    "PSP": "psp",
    
    # Microsoft
    
    "Xbox One": "xbox-one",
    "Xbox Series S/X": "xbox-series-x",
    "Xbox 360": "xbox-360",
    "Xbox": "xbox",
    
    # Nintendo
    
    "Nintendo Switch": "switch",
    "Wii U": "wii-u",
    "Wii": "wii",
    "GameCube": "gamecube",
    "Nintendo 64": "n64",
    "Nintendo 3DS": "3ds",
    "Nintendo DS": "ds",
    "Nintendo DSi": "ds",
    "Game Boy Advance": "gba",
    
    # Others
    
    "PC": "pc",
    "Dreamcast": "dreamcast"
    
}

# %% [markdown]
# ---
#
# We are going to add a new column `plat_mc` to `rawg_data` for the platform in Metacritic format. Any console not in the `platforms_metacritic` dictionary will have a `NaN` assigned.

# %%
def plat_metacritic(x):
    
    '''
    Given a string indicating a platform, returns the equivalent for Metacritic.
    
    x: String indicating a platform.
    '''
    
    if x in platforms_metacritic.keys():
        
        result = platforms_metacritic[x]
        
    else:
        
        result = np.nan
        
    return result

# %%
rawg_data['plat_mc'] = rawg_data['platform'].apply(plat_metacritic)

rawg_data
# Out:
#                               slug                         name   released  \
# 0               grand-theft-auto-v           Grand Theft Auto V 2013-09-17
# 1               grand-theft-auto-v           Grand Theft Auto V 2013-09-17
# 2               grand-theft-auto-v           Grand Theft Auto V 2013-09-17
# 3               grand-theft-auto-v           Grand Theft Auto V 2013-09-17
# 4               grand-theft-auto-v           Grand Theft Auto V 2013-09-17
# ...                            ...                          ...        ...
# 121974        docs-for-playstation         Docs for PlayStation 2016-05-18
# 121975        docs-for-playstation         Docs for PlayStation 2016-05-18
# 121976                  bee-leader                   Bee Leader 2012-05-24
# 121977  delta-strike-first-assault  Delta Strike: First Assault 2016-05-31
# 121978            kitten-sanctuary             Kitten Sanctuary 2009-03-13
#
#        suggestions_count         platform                    genres  \
# 0                    416               PC       [Action, Adventure]
# 1                    416  Xbox Series S/X       [Action, Adventure]
# 2                    416    PlayStation 5       [Action, Adventure]
# 3                    416    PlayStation 4       [Action, Adventure]
# 4                    416    PlayStation 3       [Action, Adventure]
# ...                  ...              ...                       ...
# 121974                 0    PlayStation 3                       NaN
# 121975                 0    PlayStation 4                       NaN
# 121976                45            macOS  [Action, Arcade, Casual]
# 121977               356          PS Vita                    Action
# 121978               365               PC          [Family, Puzzle]
#
#                                                    stores  \
# 0       [Epic Games, PlayStation Store, Xbox Store, Xb...
# 1       [Epic Games, PlayStation Store, Xbox Store, Xb...
# 2       [Epic Games, PlayStation Store, Xbox Store, Xb...
# 3       [Epic Games, PlayStation Store, Xbox Store, Xb...
# 4       [Epic Games, PlayStation Store, Xbox Store, Xb...
# ...                                                   ...
# 121974                                  PlayStation Store
# 121975                                  PlayStation Store
# 121976                                          App Store
# 121977                                  PlayStation Store
# 121978                                          App Store
#
#                                                      tags          esrb  \
# 0       [Singleplayer, Steam Achievements, Multiplayer...        Mature
# 1       [Singleplayer, Steam Achievements, Multiplayer...        Mature
# 2       [Singleplayer, Steam Achievements, Multiplayer...        Mature
# 3       [Singleplayer, Steam Achievements, Multiplayer...        Mature
# 4       [Singleplayer, Steam Achievements, Multiplayer...        Mature
# ...                                                   ...           ...
# 121974                      [Music, online, console, art]           NaN
# 121975                      [Music, online, console, art]           NaN
# 121976  [Cute, Physics, achievements, Music, city, Fli...           NaN
# 121977                     [combat, online, Tanks, drone]  Everyone 10+
# 121978  [Cute, Aliens, achievements, Story, fun, cats,...  Everyone 10+
#
#               plat_mc
# 0                  pc
# 1       xbox-series-x
# 2       playstation-5
# 3       playstation-4
# 4                 ps3
# ...               ...
# 121974            ps3
# 121975  playstation-4
# 121976            NaN
# 121977           vita
# 121978             pc
#
# [121979 rows x 10 columns]

# %%
rawg_data['plat_mc'].value_counts()
# Out:
# pc               57165
# playstation-4     5419
# switch            4140
# xbox-one          4075
# ps3               3485
# xbox-360          2475
# wii               2283
# ds                2182
# vita              1893
# 3ds               1690
# psp               1546
# ps2               1513
# ps                1356
# wii-u             1251
# gba                854
# xbox               671
# gamecube           625
# n64                338
# dreamcast          324
# playstation-5       77
# xbox-series-x       65
# Name: plat_mc, dtype: int64

# %% [markdown]
# Indexes seem to have set all to 0 somehow, so we will reset them with the `pd.DataFrame.reset_index()` method.

# %%
rawg_data.head()
# Out:
#                  slug                name   released suggestions_count  \
# 0  grand-theft-auto-v  Grand Theft Auto V 2013-09-17               416
# 1  grand-theft-auto-v  Grand Theft Auto V 2013-09-17               416
# 2  grand-theft-auto-v  Grand Theft Auto V 2013-09-17               416
# 3  grand-theft-auto-v  Grand Theft Auto V 2013-09-17               416
# 4  grand-theft-auto-v  Grand Theft Auto V 2013-09-17               416
#
#           platform               genres  \
# 0               PC  [Action, Adventure]
# 1  Xbox Series S/X  [Action, Adventure]
# 2    PlayStation 5  [Action, Adventure]
# 3    PlayStation 4  [Action, Adventure]
# 4    PlayStation 3  [Action, Adventure]
#
#                                               stores  \
# 0  [Epic Games, PlayStation Store, Xbox Store, Xb...
# 1  [Epic Games, PlayStation Store, Xbox Store, Xb...
# 2  [Epic Games, PlayStation Store, Xbox Store, Xb...
# 3  [Epic Games, PlayStation Store, Xbox Store, Xb...
# 4  [Epic Games, PlayStation Store, Xbox Store, Xb...
#
#                                                 tags    esrb        plat_mc
# 0  [Singleplayer, Steam Achievements, Multiplayer...  Mature             pc
# 1  [Singleplayer, Steam Achievements, Multiplayer...  Mature  xbox-series-x
# 2  [Singleplayer, Steam Achievements, Multiplayer...  Mature  playstation-5
# 3  [Singleplayer, Steam Achievements, Multiplayer...  Mature  playstation-4
# 4  [Singleplayer, Steam Achievements, Multiplayer...  Mature            ps3

# %%
rawg_data = rawg_data.reset_index(drop=True)

# %% [markdown]
# We will list the indexes of NaN in the `plat_mc` column in order to drop them.

# %%
no_metacritic = rawg_data.index[rawg_data['plat_mc'].isna()].tolist()

# %%
rawg_data = rawg_data.drop(index = no_metacritic)\
                     .reset_index(drop = True)

# %% [markdown]
# # 7. Creating URL Column
#
# We are creating a new column named `url`, which will include the hyperlink to the games' Metacritic page (if it exists). This will ease the web scraping process.

# %%
rawg_data['url'] = 'https://www.metacritic.com/game/' + rawg_data['plat_mc'] + '/' + rawg_data['slug']

rawg_data.head()
# Out:
#                  slug                name   released suggestions_count  \
# 0  grand-theft-auto-v  Grand Theft Auto V 2013-09-17               416
# 1  grand-theft-auto-v  Grand Theft Auto V 2013-09-17               416
# 2  grand-theft-auto-v  Grand Theft Auto V 2013-09-17               416
# 3  grand-theft-auto-v  Grand Theft Auto V 2013-09-17               416
# 4  grand-theft-auto-v  Grand Theft Auto V 2013-09-17               416
#
#           platform               genres  \
# 0               PC  [Action, Adventure]
# 1  Xbox Series S/X  [Action, Adventure]
# 2    PlayStation 5  [Action, Adventure]
# 3    PlayStation 4  [Action, Adventure]
# 4    PlayStation 3  [Action, Adventure]
#
#                                               stores  \
# 0  [Epic Games, PlayStation Store, Xbox Store, Xb...
# 1  [Epic Games, PlayStation Store, Xbox Store, Xb...
# 2  [Epic Games, PlayStation Store, Xbox Store, Xb...
# 3  [Epic Games, PlayStation Store, Xbox Store, Xb...
# 4  [Epic Games, PlayStation Store, Xbox Store, Xb...
#
#                                                 tags    esrb        plat_mc  \
# 0  [Singleplayer, Steam Achievements, Multiplayer...  Mature             pc
# 1  [Singleplayer, Steam Achievements, Multiplayer...  Mature  xbox-series-x
# 2  [Singleplayer, Steam Achievements, Multiplayer...  Mature  playstation-5
# 3  [Singleplayer, Steam Achievements, Multiplayer...  Mature  playstation-4
# 4  [Singleplayer, Steam Achievements, Multiplayer...  Mature            ps3
#
#                                                  url
# 0  https://www.metacritic.com/game/pc/grand-theft...
# 1  https://www.metacritic.com/game/xbox-series-x/...
# 2  https://www.metacritic.com/game/playstation-5/...
# 3  https://www.metacritic.com/game/playstation-4/...
# 4  https://www.metacritic.com/game/ps3/grand-thef...

# %% [markdown]
# # 8. Saving Dataset

# %%
rawg_data.to_csv("Files/02_rawg_metacritic_url.csv", encoding='utf-8', index=False)
