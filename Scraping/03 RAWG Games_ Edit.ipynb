# %%
import pandas as pd
import numpy as np
# import copy
from ast import literal_eval ### to convert dicts stored as str to str

# %%
def col_series(column, series, long = False, list_like = True):
    
    '''
    Function returning a pd.Series containing lists or values nested in a column from the RAWG games dataset.
    
    Keyword arguments:
    column -- The name of the column in the dataset.
    series -- The values stored as a pd.Series object in the column.
    long -- Whether if the column has the highest amount of nesting or not. (default=False)
    list_like -- Whether if the column contains lists or dictionaries. (default=True)
    
    '''
    
    aux_big = list()
    
    if long == True:        
        key = column[:-1] # Strip the s so that the key works  
        
        for row in series:
            aux = list()
            
            for item in row:
                aux.append(item[key]['name'])
                
            if len(aux) == 1:
                    aux = item[key]['name']
                
            if len(aux) <= 0:
                    aux = np.nan
                
            aux_big.append(aux)
                
    else:      
        if list_like == True:
            for row in series:
                aux = list()
                
                for item in row:
                    aux.append(item['name'])
                
                if len(aux) == 1:
                    aux = item['name']
                    
                elif len(aux) <= 0:
                    aux = np.nan
                    
                aux_big.append(aux)

        else:
            for row in series:
                aux = np.nan
                
                if not np.any(pd.isna(row)):
                    aux = row['name']
                    
                aux_big.append(aux)
    
    return pd.Series(aux_big, name = column)

# %%
chunk_size = 10000
count = 1

series_df = pd.DataFrame()
others = pd.DataFrame(columns = ['id','slug','name','released','tba','metacritic','suggestions_count','updated'])
others_aux = pd.DataFrame()

platforms = pd.Series(dtype=object, name = 'platforms')
genres = pd.Series(dtype=object, name = 'genres')
stores = pd.Series(dtype=object, name = 'stores')
tags = pd.Series(dtype=object, name = 'tags')
esrb = pd.Series(dtype=object, name = 'esrb_rating')


for chunk in pd.read_csv('rawg_games.csv', sep = '^', chunksize = chunk_size, index_col = None):
    
    ####################################
    ##  Dropping unnecessary columns  ##
    ####################################
    
    data = chunk[['id','slug','name','released','tba','metacritic','suggestions_count',
                'updated','platforms','genres','stores','tags','esrb_rating']].copy()
    
    ###########################
    ##  Str to list of dict  ##
    ###########################
    
    data['platforms'] = data['platforms'].apply(lambda x: literal_eval(x) if pd.notnull(x) else x)
    data['genres'] = data['genres'].apply(lambda x: literal_eval(x) if pd.notnull(x) else x)
    data['stores'] = data['stores'].apply(lambda x: literal_eval(x) if pd.notnull(x) else x)
    data['tags'] = data['tags'].apply(lambda x: literal_eval(x) if pd.notnull(x) else x)
    data['esrb_rating'] = data['esrb_rating'].apply(lambda x: literal_eval(x) if pd.notnull(x) else x)
    
    #############################################
    ##  Slice column to get YYYY-MM-DD format  ##
    #############################################
    
    data['updated'] = data['updated'].str.slice(stop=-9) # We slice the 'updated' col so that it only shows the YYYY-MM-DD format
    
    ##################################
    ##  Getting the values we want  ##
    ##################################
    
    aux = pd.DataFrame(columns = ['id','name','released','tba','metacritic','suggestions_count','updated'])
    
    for cols, series in data.iteritems():

        if cols == 'platforms':
            platforms = platforms.append(col_series(cols, series, long = True)).reset_index(drop=True)

        elif cols == 'genres':
            genres = genres.append(col_series(cols, series)).reset_index(drop=True)

        elif cols == 'stores':         
            stores = stores.append(col_series(cols, series, long = True)).reset_index(drop=True)

        elif cols == 'tags':          
            tags = tags.append(col_series(cols, series)).reset_index(drop=True)

        elif cols == 'esrb_rating':
            esrb = esrb.append(col_series(cols, series, list_like = False)).reset_index(drop=True)
        
        else:
            aux[cols] = pd.Series(series, name = cols)
            

    others = pd.concat([others, aux])
    series_df = pd.concat([platforms, genres, stores, tags, esrb], axis = 1)
                
    ##################################################            
    ##  Output saved by concatenation to DataFrame  ##
    ##################################################
    
    print('Chunk #'+ str(count))
    count += 1
    
first_half = others.reset_index()
second_half = series_df.reset_index()

output = first_half.merge(second_half)
    
print('Finished!')
# Out:
# Chunk #1
# Chunk #2
# Chunk #3
# Chunk #4
# Chunk #5
# Chunk #6
# Chunk #7
# Chunk #8
# Chunk #9
# Chunk #10
# Chunk #11
# Chunk #12
# Chunk #13
# Chunk #14
# Chunk #15
# Chunk #16
# Chunk #17
# Chunk #18
# Chunk #19
# Chunk #20
# Chunk #21
# Chunk #22
# Chunk #23
# Chunk #24
# Chunk #25
# Chunk #26
# Chunk #27
# Chunk #28
# Chunk #29
# Chunk #30
# Chunk #31
# Chunk #32
# Chunk #33
# Chunk #34
# Chunk #35
# Chunk #36
# Chunk #37
# Chunk #38
# Chunk #39
# Chunk #40
# Chunk #41
# Chunk #42
# Chunk #43
# Chunk #44
# Chunk #45
# Chunk #46
# Chunk #47
# Chunk #48
# Chunk #49
# Chunk #50
# Chunk #51
# Chunk #52
# Chunk #53
# Finished!

# %%
output
# Out:
#          index    id                        slug                         name  \
# 0            0  3498          grand-theft-auto-v           Grand Theft Auto V
# 1            1  4200                    portal-2                     Portal 2
# 2            2  3328     the-witcher-3-wild-hunt     The Witcher 3: Wild Hunt
# 3            3  5286                 tomb-raider           Tomb Raider (2013)
# 4            4  5679  the-elder-scrolls-v-skyrim  The Elder Scrolls V: Skyrim
# ...        ...   ...                         ...                          ...
# 521608  521608  1973                    no-human                    No, Human
# 521609  521609  1971                 descend-rpg                  Descend RPG
# 521610  521610  1957                 hodappybird                  HodappyBird
# 521611  521611  1688  brigands-and-barbarians-hd   Brigands and Barbarians HD
# 521612  521612  1339     siralim-2-rpg-roguelike  Siralim 2 (RPG / Roguelike)
#
#           released    tba  metacritic suggestions_count     updated  \
# 0       2013-09-17  False        97.0               416  2021-03-03
# 1       2011-04-18  False        95.0               582  2020-08-03
# 2       2015-05-18  False        92.0               678  2020-10-02
# 3       2013-03-05  False        86.0               664  2020-08-03
# 4       2011-11-11  False        94.0               621  2020-07-06
# ...            ...    ...         ...               ...         ...
# 521608  2010-08-24  False         NaN                78  2019-10-22
# 521609  2011-10-13  False         NaN               140  2019-10-22
# 521610  2014-04-17  False         NaN                67  2019-10-22
# 521611  2012-11-14  False         NaN               225  2019-10-22
# 521612  2016-09-11  False         NaN               187  2019-10-22
#
#                                                 platforms  \
# 0       [PC, Xbox Series S/X, PlayStation 5, PlayStati...
# 1       [Xbox One, PlayStation 3, PC, Xbox 360, Linux,...
# 2          [PC, Xbox One, Nintendo Switch, PlayStation 4]
# 3       [PC, PlayStation 4, PlayStation 3, Xbox 360, X...
# 4          [PC, PlayStation 3, Xbox 360, Nintendo Switch]
# ...                                                   ...
# 521608                                                iOS
# 521609                                                iOS
# 521610                                                iOS
# 521611                                                iOS
# 521612                                                iOS
#
#                           genres  \
# 0            [Action, Adventure]
# 1              [Shooter, Puzzle]
# 2       [Action, Adventure, RPG]
# 3            [Action, Adventure]
# 4                  [Action, RPG]
# ...                          ...
# 521608          [Action, Puzzle]
# 521609                       RPG
# 521610          [Action, Arcade]
# 521611          [Adventure, RPG]
# 521612           [RPG, Strategy]
#
#                                                    stores  \
# 0       [Epic Games, PlayStation Store, Xbox Store, Xb...
# 1       [Xbox Store, Xbox 360 Store, PlayStation Store...
# 2             [GOG, Xbox Store, Steam, PlayStation Store]
# 3       [App Store, Google Play, PlayStation Store, St...
# 4       [Xbox 360 Store, Nintendo Store, Steam, PlaySt...
# ...                                                   ...
# 521608                                          App Store
# 521609                                          App Store
# 521610                                          App Store
# 521611                                          App Store
# 521612                                          App Store
#
#                                                      tags   esrb_rating
# 0       [Singleplayer, Steam Achievements, Multiplayer...        Mature
# 1       [Singleplayer, Steam Achievements, Multiplayer...  Everyone 10+
# 2       [Singleplayer, Atmospheric, Full controller su...        Mature
# 3       [Singleplayer, Multiplayer, Atmospheric, Full ...        Mature
# 4       [Singleplayer, Steam Achievements, steam-tradi...        Mature
# ...                                                   ...           ...
# 521608     [Physics, Music, Story, Relaxing, Destruction]  Everyone 10+
# 521609  [RPG, Mystery, combat, battle, party, fight, s...  Everyone 10+
# 521610                                      [color, bird]  Everyone 10+
# 521611  [RPG, Fantasy, War, JRPG, combat, Dragons, pri...  Everyone 10+
# 521612  [RPG, Space, battle, fight, treasure, Endless,...           NaN
#
# [521613 rows x 14 columns]

# %%
games = output.drop('index', axis = 1)
games
# Out:
#           id                        slug                         name  \
# 0       3498          grand-theft-auto-v           Grand Theft Auto V
# 1       4200                    portal-2                     Portal 2
# 2       3328     the-witcher-3-wild-hunt     The Witcher 3: Wild Hunt
# 3       5286                 tomb-raider           Tomb Raider (2013)
# 4       5679  the-elder-scrolls-v-skyrim  The Elder Scrolls V: Skyrim
# ...      ...                         ...                          ...
# 521608  1973                    no-human                    No, Human
# 521609  1971                 descend-rpg                  Descend RPG
# 521610  1957                 hodappybird                  HodappyBird
# 521611  1688  brigands-and-barbarians-hd   Brigands and Barbarians HD
# 521612  1339     siralim-2-rpg-roguelike  Siralim 2 (RPG / Roguelike)
#
#           released    tba  metacritic suggestions_count     updated  \
# 0       2013-09-17  False        97.0               416  2021-03-03
# 1       2011-04-18  False        95.0               582  2020-08-03
# 2       2015-05-18  False        92.0               678  2020-10-02
# 3       2013-03-05  False        86.0               664  2020-08-03
# 4       2011-11-11  False        94.0               621  2020-07-06
# ...            ...    ...         ...               ...         ...
# 521608  2010-08-24  False         NaN                78  2019-10-22
# 521609  2011-10-13  False         NaN               140  2019-10-22
# 521610  2014-04-17  False         NaN                67  2019-10-22
# 521611  2012-11-14  False         NaN               225  2019-10-22
# 521612  2016-09-11  False         NaN               187  2019-10-22
#
#                                                 platforms  \
# 0       [PC, Xbox Series S/X, PlayStation 5, PlayStati...
# 1       [Xbox One, PlayStation 3, PC, Xbox 360, Linux,...
# 2          [PC, Xbox One, Nintendo Switch, PlayStation 4]
# 3       [PC, PlayStation 4, PlayStation 3, Xbox 360, X...
# 4          [PC, PlayStation 3, Xbox 360, Nintendo Switch]
# ...                                                   ...
# 521608                                                iOS
# 521609                                                iOS
# 521610                                                iOS
# 521611                                                iOS
# 521612                                                iOS
#
#                           genres  \
# 0            [Action, Adventure]
# 1              [Shooter, Puzzle]
# 2       [Action, Adventure, RPG]
# 3            [Action, Adventure]
# 4                  [Action, RPG]
# ...                          ...
# 521608          [Action, Puzzle]
# 521609                       RPG
# 521610          [Action, Arcade]
# 521611          [Adventure, RPG]
# 521612           [RPG, Strategy]
#
#                                                    stores  \
# 0       [Epic Games, PlayStation Store, Xbox Store, Xb...
# 1       [Xbox Store, Xbox 360 Store, PlayStation Store...
# 2             [GOG, Xbox Store, Steam, PlayStation Store]
# 3       [App Store, Google Play, PlayStation Store, St...
# 4       [Xbox 360 Store, Nintendo Store, Steam, PlaySt...
# ...                                                   ...
# 521608                                          App Store
# 521609                                          App Store
# 521610                                          App Store
# 521611                                          App Store
# 521612                                          App Store
#
#                                                      tags   esrb_rating
# 0       [Singleplayer, Steam Achievements, Multiplayer...        Mature
# 1       [Singleplayer, Steam Achievements, Multiplayer...  Everyone 10+
# 2       [Singleplayer, Atmospheric, Full controller su...        Mature
# 3       [Singleplayer, Multiplayer, Atmospheric, Full ...        Mature
# 4       [Singleplayer, Steam Achievements, steam-tradi...        Mature
# ...                                                   ...           ...
# 521608     [Physics, Music, Story, Relaxing, Destruction]  Everyone 10+
# 521609  [RPG, Mystery, combat, battle, party, fight, s...  Everyone 10+
# 521610                                      [color, bird]  Everyone 10+
# 521611  [RPG, Fantasy, War, JRPG, combat, Dragons, pri...  Everyone 10+
# 521612  [RPG, Space, battle, fight, treasure, Endless,...           NaN
#
# [521613 rows x 13 columns]

# %%
genres = list()

for col, series in games.iteritems():
    if col == 'genres':
        for row in series:
            if type(row) != list:
                if row not in genres:
                    genres.append(row)
                
            else:
                for item in row:
                    if item not in genres:
                        genres.append(item)

pd.Series(genres).reset_index()
# Out:
#     index                      0
# 0       0                 Action
# 1       1              Adventure
# 2       2                Shooter
# 3       3                 Puzzle
# 4       4                    RPG
# 5       5                  Indie
# 6       6             Platformer
# 7       7                 Sports
# 8       8                 Racing
# 9       9  Massively Multiplayer
# 10     10                 Arcade
# 11     11               Strategy
# 12     12               Fighting
# 13     13             Simulation
# 14     14                 Casual
# 15     15                 Family
# 16     16            Educational
# 17     17            Board Games
# 18     18                   Card
# 19     19                    NaN

# %%
uniques = list()

for col, series in games.iteritems():
    if col == 'platforms':
        for row in series:
            if type(row) != list:
                if row not in uniques:
                    uniques.append(row)
                
            else:
                for item in row:
                    if item not in uniques:
                        uniques.append(item)

pd.Series(uniques).reset_index()
# Out:
#     index                   0
# 0       0                  PC
# 1       1     Xbox Series S/X
# 2       2       PlayStation 5
# 3       3       PlayStation 4
# 4       4       PlayStation 3
# 5       5            Xbox 360
# 6       6            Xbox One
# 7       7               Linux
# 8       8               macOS
# 9       9     Nintendo Switch
# 10     10             Android
# 11     11                 iOS
# 12     12                Xbox
# 13     13             PS Vita
# 14     14                 Web
# 15     15        Nintendo 3DS
# 16     16               Wii U
# 17     17       PlayStation 2
# 18     18   Classic Macintosh
# 19     19         Nintendo DS
# 20     20                 Wii
# 21     21           Dreamcast
# 22     22            GameCube
# 23     23         PlayStation
# 24     24            Game Boy
# 25     25                 PSP
# 26     26    Game Boy Advance
# 27     27         Nintendo 64
# 28     28   Commodore / Amiga
# 29     29        Nintendo DSi
# 30     30      Game Boy Color
# 31     31             Neo Geo
# 32     32            Apple II
# 33     33             SEGA CD
# 34     34         SEGA Saturn
# 35     35  SEGA Master System
# 36     36           Game Gear
# 37     37                SNES
# 38     38             Genesis
# 39     39              Jaguar
# 40     40            Atari ST
# 41     41         Atari 8-bit
# 42     42                 NES
# 43     43                 3DO
# 44     44            SEGA 32X
# 45     45          Atari Lynx
# 46     46          Atari 2600
# 47     47          Atari 5200
# 48     48          Atari 7800
# 49     49                 NaN
# 50     50          Atari XEGS
# 51     51     Atari Flashback

# %% [markdown]
# These are the unique platforms in the data set.
#
# - iOS, Android and Web should be dropped.
# - We have to decide whether we want old consoles to be included here or not (from what year onward will be considered valid?)

# %%
games.to_csv("rawg_games_smaller.csv", encoding='utf-8', index=False)
