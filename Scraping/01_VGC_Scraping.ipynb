# %%
from bs4 import BeautifulSoup, element
import urllib
import pandas as pd
import numpy as np

# %% [markdown]
# # Scraping VGChartz
#
# We will define a function to scrape this web site, as we will have to do it several times little by little, as it will often return the `HTTP error 503 (Service Unavailable)`.
#
# We are going to try scraping 5 pages at once, making us run the function 12 times (we are going to show 1000 results per page).

# %%
urlhead = 'https://www.vgchartz.com/games/games.php?page='
urltail = '&console=&region=All&developer=&publisher=&genre=&boxart=Both&ownership=Both'
urltail += '&results=1000&order=Sales&showtotalsales=1&shownasales=1&showpalsales=1&showjapansales=1'
urltail += '&showothersales=1&showpublisher=1&showdeveloper=1&showreleasedate=1&showlastupdate=1'
urltail += '&showvgchartzscore=1&showcriticscore=1&showuserscore=1&showshipped=1'

# %%
def scrape(urlhead, urltail, p_start, p_finish, file_n = 1):
    
    '''
    Given a URL head, a URL tail and the range of pages we want to scrape, it returns a dataframe with the scraped data.
    urlhead : The url of the web we want to scrape (VGChartz in this case) until 'page=?' included.
    urltail : Same as above, but everything after the page number.
    p_start : The first page we want to scrape.
    p_finish : The (last page - 1) we want to scrape.
    file_n : The number we want to give our .csv output file.
    '''
    
    # We initialize the lists and not outside due to the high likelihood of getting the 503 error, so that wo don't get duplicates every time that happens.
    title = []
    platform = []
    publisher = []
    developer = []
    vgc_score = []
    critic_score = []
    user_score = []
    total_shipped = []
    total_sales = []
    sales_na = []
    sales_pal = []
    sales_jp = []
    sales_ot = []
    release = []
    update = []
    
    # To check for how many values we scraped. 
    rec_count = 0
    
    for page in range(p_start, p_finish):
        
        surl = urlhead + str(page) + urltail
        r = urllib.request.urlopen(surl).read()
        soup = BeautifulSoup(r, features="lxml")
        print(f"Page: {page}")

        chart = soup.find('div', id='generalBody').find('table')

        for row in chart.find_all('tr')[3:]:
            try:
                col = row.find_all('td')

                # extract data into column data

                column_2 = col[2].find('a').string.strip()      # Title
                column_3 = col[3].find('img')['alt'].strip()    # Platform
                column_4 = col[4].string.strip()                # Publisher
                column_5 = col[5].string.strip()                # Developer
                column_6 = col[6].string.strip()                # VGChartz Score
                column_7 = col[7].string.strip()                # Critic Score
                column_8 = col[8].string.strip()                # User Score
                column_9 = col[9].string.strip()                # Total Shipped
                column_10 = col[10].string.strip()              # Total Sales
                column_11 = col[11].string.strip()              # NA Sales
                column_12 = col[12].string.strip()              # PAL Sales (EU)
                column_13 = col[13].string.strip()              # Japan Sales
                column_14 = col[14].string.strip()              # Other Sales
                column_15 = col[15].string.strip()              # Release Date
                column_16 = col[16].string.strip()              # Last Update

                # Add Data to columns
                # Adding data only if able to read all of the columns

                title.append(column_2)
                platform.append(column_3)
                publisher.append(column_4)
                developer.append(column_5)
                vgc_score.append(column_6)
                critic_score.append(column_7)
                user_score.append(column_8)
                total_shipped.append(column_9)
                total_sales.append(column_10)
                sales_na.append(column_11)
                sales_pal.append(column_12)
                sales_jp.append(column_13)
                sales_ot.append(column_14)
                release.append(column_15)
                update.append(column_16)

                rec_count += 1

            except:
                print('Got Exception')
                continue

    columns = {'Title': title, 'Platform': platform, 'Publisher': publisher, 'Developer': developer, 'VGC_Score': vgc_score,
               'Critic_Score': critic_score, 'User_Score': user_score, 'Total_Shipped': total_shipped, 'Total_Sales': total_sales, 'NA_Sales': sales_na,
               'EU_Sales': sales_pal, 'JP_Sales': sales_jp, 'Other_Sales': sales_ot, 'Release': release, 'Last_Update': update}

    print (rec_count)
    
    df = pd.DataFrame(columns)
    
    print(df)
    
    df = df[['Title', 'Platform', 'Publisher', 'Developer', 'VGC_Score', 'Critic_Score', 'User_Score', 'Total_Shipped', 'Total_Sales', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales',
             'Release', 'Last_Update']]
    
    # Numbering the output
    
    if file_n < 10:
        file_n = '0' + str(file_n)
        
    else:
        file_n = str(file_n)
    
    filename = "vgsales_" + file_n + ".csv"
    df.to_csv(filename, sep=",", encoding='utf-8')

    print('done!')
    
    return df

# %% [markdown]
# ---
# Let's proceed with the scraping.

# %%
df1 = scrape(urlhead, urltail, 1, 6)
# Out:
# Page: 1
# Page: 2
# Page: 3
# Page: 4
# Page: 5
# 5000
#                                Title Platform                    Publisher  \
# 0                             Tetris   Series                      Unknown
# 1                        Super Mario   Series                     Nintendo
# 2                            Pokemon   Series                     Nintendo
# 3                   Grand Theft Auto   Series               Rockstar Games
# 4                               FIFA   Series                    EA Sports
# ...                              ...      ...                          ...
# 4995             Jampack Summer 2002      PS2  Sony Computer Entertainment
# 4996                 Trivial Pursuit      Wii              Electronic Arts
# 4997     FIFA World Cup Germany 2006      PS2                    EA Sports
# 4998  Wreckless: ThE YaKuza MisSiOns       XB                   Activision
# 4999          Anomaly: Warzone Earth       PC                      Unknown
#
#                                   Developer VGC_Score Critic_Score User_Score  \
# 0                           Alexey Pajitnov       N/A          N/A        N/A
# 1                                  Nintendo       N/A          N/A        N/A
# 2                                Game Freak       N/A          N/A        N/A
# 3                            Rockstar North       N/A          N/A        N/A
# 4     Extended Play Productions (1991-1997)       N/A          N/A        N/A
# ...                                     ...       ...          ...        ...
# 4995    Sony Computer Entertainment America       N/A          N/A        N/A
# 4996                  Adrenalin Interactive       6.0          7.3        N/A
# 4997                              EA Canada       N/A          7.9        N/A
# 4998                    Bunkasha Publishing       N/A          N/A        N/A
# 4999                         11 bit studios       N/A          7.9        N/A
#
#      Total_Shipped Total_Sales NA_Sales EU_Sales JP_Sales Other_Sales  \
# 0          496.00m         N/A      N/A      N/A      N/A         N/A
# 1          372.86m         N/A      N/A      N/A      N/A         N/A
# 2          369.88m         N/A      N/A      N/A      N/A         N/A
# 3          335.00m         N/A      N/A      N/A      N/A         N/A
# 4          325.00m         N/A      N/A      N/A      N/A         N/A
# ...            ...         ...      ...      ...      ...         ...
# 4995           N/A       0.57m    0.28m    0.22m      N/A       0.07m
# 4996           N/A       0.57m    0.20m    0.30m      N/A       0.06m
# 4997           N/A       0.57m    0.47m    0.02m      N/A       0.08m
# 4998           N/A       0.57m    0.42m    0.11m    0.02m       0.02m
# 4999         0.57m         N/A      N/A      N/A      N/A         N/A
#
#           Release  Last_Update
# 0     06th Jun 84  27th Feb 20
# 1     20th Jul 83  20th Feb 20
# 2     28th Sep 98  03rd Feb 20
# 3     27th Mar 98  03rd Feb 20
# 4     15th Dec 93  03rd Feb 20
# ...           ...          ...
# 4995  28th May 02          N/A
# 4996  10th Mar 09          N/A
# 4997  24th Apr 06          N/A
# 4998  04th Feb 02          N/A
# 4999  08th Apr 11          N/A
#
# [5000 rows x 15 columns]
# done!

# %%
df2 = scrape(urlhead, urltail, 6, 11, file_n = 2)
# Out:
# Page: 6
# Page: 7
# Page: 8
# Page: 9
# Page: 10
# 5000
#                                                   Title Platform  \
# 0                            Starlink: Battle for Atlas       NS
# 1                                       Super Bomberman     SNES
# 2                                            Top Spin 3      PS3
# 3       SpongeBob SquarePants: Battle for Bikini Bottom       XB
# 4                                                    Up      Wii
# ...                                                 ...      ...
# 4995                                    Among The Sleep       PC
# 4996  Kouchuu Ouja Mushi King: Greatest Champion e n...       DS
# 4997                                     Parlor! Mini 4     SNES
# 4998                                  Breath of Fire II      GBA
# 4999                                          BARRIER X       PC
#
#              Publisher           Developer VGC_Score Critic_Score User_Score  \
# 0              Ubisoft     Ubisoft Toronto       N/A          7.5        6.0
# 1          Hudson Soft            Produce!       N/A          N/A        N/A
# 2            2K Sports     Pam Development       N/A          7.8        N/A
# 3                  THQ  Heavy Iron Studios       N/A          6.7        N/A
# 4                  THQ                 THQ       N/A          N/A        N/A
# ...                ...                 ...       ...          ...        ...
# 4995  Krillbite Studio    Krillbite Studio       7.2          N/A        N/A
# 4996              Sega                Sega       N/A          N/A        N/A
# 4997    Nippon Telenet      Nippon Telenet       N/A          N/A        N/A
# 4998            Capcom              Capcom       N/A          8.6        N/A
# 4999           Unknown              Noclip       N/A          N/A        N/A
#
#      Total_Shipped Total_Sales NA_Sales EU_Sales JP_Sales Other_Sales  \
# 0              N/A       0.57m    0.35m    0.17m      N/A       0.05m
# 1              N/A       0.57m      N/A      N/A    0.57m       0.00m
# 2              N/A       0.57m    0.08m    0.37m    0.00m       0.12m
# 3              N/A       0.57m    0.45m    0.10m      N/A       0.02m
# 4              N/A       0.57m    0.22m    0.29m      N/A       0.06m
# ...            ...         ...      ...      ...      ...         ...
# 4995         0.19m         N/A      N/A      N/A      N/A         N/A
# 4996           N/A       0.19m      N/A      N/A    0.19m         N/A
# 4997           N/A       0.19m      N/A      N/A    0.19m         N/A
# 4998           N/A       0.19m    0.14m    0.05m      N/A       0.00m
# 4999         0.19m         N/A      N/A      N/A      N/A         N/A
#
#           Release  Last_Update
# 0     16th Oct 18  22nd Mar 19
# 1     01st Jan 93          N/A
# 2     23rd Jun 08          N/A
# 3     31st Oct 03          N/A
# 4     26th May 09          N/A
# ...           ...          ...
# 4995  29th May 14  23rd Nov 18
# 4996  08th Dec 05          N/A
# 4997  29th Nov 96          N/A
# 4998  16th Apr 02          N/A
# 4999          N/A  28th Feb 19
#
# [5000 rows x 15 columns]
# done!

# %%
df3 = scrape(urlhead, urltail, 11, 16, file_n = 3)
# Out:
# Page: 11
# Page: 12
# Page: 13
# Page: 14
# Page: 15
# 5000
#                                Title Platform                    Publisher  \
# 0     Danganronpa 2: Goodbye Despair      PSP                        Spike
# 1                              Conan     X360                          THQ
# 2            Ice Age 2: The Meltdown       GC                Vivendi Games
# 3          Petz Pony: Beauty Pageant       DS                      Ubisoft
# 4                        Steins;Gate      PSP              Kadokawa Shoten
# ...                              ...      ...                          ...
# 4995     Discovery Kids: Parrot Pals       DS                    505 Games
# 4996        Styx: Shards of Darkness      PS4       Focus Home Interactive
# 4997                      Torchlight       PC  Perfect World Entertainment
# 4998                     Chaos;Child      PSV                        PQube
# 4999        Archer Maclean's 3D Pool      GBA          Crave Entertainment
#
#                            Developer VGC_Score Critic_Score User_Score  \
# 0                     Spike Chunsoft       N/A          N/A        N/A
# 1                Nihilistic Software       N/A          7.1        N/A
# 2     Eurocom Entertainment Software       N/A          7.4        N/A
# 3                     HotGen Studios       N/A          N/A        N/A
# 4                             Nitro+       N/A          N/A        N/A
# ...                              ...       ...          ...        ...
# 4995                       505 Games       N/A          N/A        N/A
# 4996                  Cyanide Studio       N/A          N/A        N/A
# 4997                     Runic Games       N/A          8.4        N/A
# 4998                       5pb. Inc.       N/A          N/A        N/A
# 4999             Awesome Productions       N/A          N/A        N/A
#
#      Total_Shipped Total_Sales NA_Sales EU_Sales JP_Sales Other_Sales  \
# 0              N/A       0.19m      N/A      N/A    0.19m         N/A
# 1              N/A       0.19m    0.16m    0.02m      N/A       0.01m
# 2              N/A       0.19m    0.15m    0.04m      N/A       0.01m
# 3              N/A       0.19m    0.18m      N/A      N/A       0.01m
# 4              N/A       0.19m      N/A      N/A    0.19m         N/A
# ...            ...         ...      ...      ...      ...         ...
# 4995           N/A       0.07m    0.07m      N/A      N/A       0.01m
# 4996           N/A       0.07m    0.06m      N/A      N/A       0.01m
# 4997           N/A       0.07m      N/A    0.06m      N/A       0.01m
# 4998           N/A       0.07m      N/A    0.00m    0.07m       0.00m
# 4999           N/A       0.07m    0.05m    0.02m      N/A       0.00m
#
#           Release  Last_Update
# 0     26th Jul 12  11th Jan 18
# 1     23rd Oct 07          N/A
# 2     14th Mar 06          N/A
# 3     13th Oct 09          N/A
# 4     23rd Jun 11  04th Jul 18
# ...           ...          ...
# 4995  16th Jun 09          N/A
# 4996  14th Mar 17  06th Jan 18
# 4997  27th Oct 09          N/A
# 4998  24th Oct 17  24th Mar 19
# 4999  03rd Nov 04          N/A
#
# [5000 rows x 15 columns]
# done!

# %%
df4 = scrape(urlhead, urltail, 16, 21, file_n = 4)
# Out:
# Page: 16
# Page: 17
# Page: 18
# Page: 19
# Page: 20
# 5000
#                                                   Title Platform  \
# 0                         Tak: The Great Juju Challenge       XB
# 1                                    TMNT: Mutant Melee       GC
# 2                                Combat: Task Force 121       XB
# 3                                             Enchanter       PC
# 4                                            Speed Zone      Wii
# ...                                                 ...      ...
# 4995  Super Robot Monkey Team: Game Boy Advance Vide...      GBA
# 4996                                         Freekstyle      GBA
# 4997                                    Aa Megami-samaa      PS2
# 4998                              Battle Worlds: Kronos       PC
# 4999                 Bunmei Kaika: Aoiza Ibunroku Saien      PSP
#
#                   Publisher                             Developer VGC_Score  \
# 0                       THQ                    Avalanche Software       N/A
# 1                    Konami  Konami Computer Entertainment Hawaii       N/A
# 2              Groove Games                   Direct Action Games       N/A
# 3                   Infocom                         Infocom, Inc.       N/A
# 4               Detn8 Games                     Awesome Play Ltd.       N/A
# ...                     ...                                   ...       ...
# 4995                Majesco                         Majesco Games       N/A
# 4996              DSI Games                              Full Fat       N/A
# 4997  Marvelous Interactive                 Marvelous Interactive       N/A
# 4998         KING Art Games                        KING Art Games       N/A
# 4999      FuRyu Corporation                               Unknown       N/A
#
#      Critic_Score User_Score Total_Shipped Total_Sales NA_Sales EU_Sales  \
# 0             N/A        N/A           N/A       0.07m    0.05m    0.02m
# 1             4.2        N/A           N/A       0.07m    0.06m    0.01m
# 2             N/A        N/A           N/A       0.07m    0.05m    0.02m
# 3             N/A        N/A         0.07m         N/A      N/A      N/A
# 4             N/A        N/A           N/A       0.07m    0.01m    0.05m
# ...           ...        ...           ...         ...      ...      ...
# 4995          N/A        N/A           N/A       0.01m    0.01m    0.00m
# 4996          7.2        N/A           N/A       0.01m    0.01m    0.00m
# 4997          N/A        N/A           N/A       0.01m      N/A      N/A
# 4998          N/A        N/A           N/A       0.01m      N/A    0.01m
# 4999          N/A        N/A           N/A       0.01m      N/A      N/A
#
#      JP_Sales Other_Sales      Release  Last_Update
# 0         N/A       0.00m  19th Sep 05          N/A
# 1         N/A       0.00m  16th Mar 05          N/A
# 2         N/A       0.00m  27th Mar 05          N/A
# 3         N/A         N/A  01st Jan 83          N/A
# 4         N/A       0.01m  18th Aug 09          N/A
# ...       ...         ...          ...          ...
# 4995      N/A       0.00m  04th Apr 05          N/A
# 4996      N/A       0.00m  30th Aug 03          N/A
# 4997    0.01m         N/A  22nd Feb 07          N/A
# 4998      N/A       0.00m  04th Nov 13  01st Aug 18
# 4999    0.01m         N/A  17th May 12          N/A
#
# [5000 rows x 15 columns]
# done!

# %%
df5 = scrape(urlhead, urltail, 21, 26, file_n = 5)
# Out:
# Page: 21
# Page: 22
# Page: 23
# Page: 24
# Page: 25
# 5000
#                                                   Title Platform  \
# 0                                       Groovin' Blocks      Wii
# 1                             Marvel: Ultimate Alliance       PC
# 2        Tomoyo After: It's a Wonderful Life CS Edition      PS2
# 3                                             Flashback      PS4
# 4                                        Bakumatsu Rock      PSP
# ...                                                 ...      ...
# 4995  Bakumatsu Rouman Dai Ni Maku: Gekka no Kenshi ...       NG
# 4996                  Bakumatsu Rouman: Gekka no Kenshi       PS
# 4997              Bakumatsu Rouman: Gekka no Kenshi 1-2      PS2
# 4998                                   Bakuretsu Akindo       PS
# 4999                                   Bakuretsu Hunter      SAT
#
#                     Publisher                 Developer VGC_Score  \
# 0                   Zoo Games        Empty Clip Studios       N/A
# 1                  Activision            Raven Software       N/A
# 2                   Prototype                       Key       N/A
# 3                    Microids              Paul Cuisset       N/A
# 4     Marvelous Entertainment                   Unknown       N/A
# ...                       ...                       ...       ...
# 4995                      SNK           SNK Corporation       N/A
# 4996                      SNK           SNK Corporation       N/A
# 4997             SNK Playmore  SNK Playmore Corporation       N/A
# 4998                 Astec 21                  Astec 21       N/A
# 4999                    I'Max                     I'Max       N/A
#
#      Critic_Score User_Score Total_Shipped Total_Sales NA_Sales EU_Sales  \
# 0             N/A        N/A           N/A       0.01m    0.01m      N/A
# 1             8.4        N/A           N/A       0.01m    0.01m    0.00m
# 2             N/A        N/A           N/A       0.01m      N/A      N/A
# 3             N/A        N/A           N/A       0.01m    0.01m      N/A
# 4             N/A        N/A           N/A       0.01m      N/A      N/A
# ...           ...        ...           ...         ...      ...      ...
# 4995          N/A        N/A           N/A         N/A      N/A      N/A
# 4996          N/A        N/A           N/A         N/A      N/A      N/A
# 4997          N/A        N/A           N/A         N/A      N/A      N/A
# 4998          N/A        N/A           N/A         N/A      N/A      N/A
# 4999          N/A        N/A           N/A         N/A      N/A      N/A
#
#      JP_Sales Other_Sales      Release  Last_Update
# 0         N/A       0.00m  11th Aug 09          N/A
# 1         N/A       0.00m  24th Oct 06          N/A
# 2       0.01m         N/A  25th Jan 07          N/A
# 3         N/A       0.00m  20th Nov 18  31st Oct 18
# 4       0.01m         N/A  27th Feb 14          N/A
# ...       ...         ...          ...          ...
# 4995      N/A         N/A  27th Feb 99          N/A
# 4996      N/A         N/A  25th Feb 99          N/A
# 4997      N/A         N/A  12th Jan 06          N/A
# 4998      N/A         N/A  22nd Mar 96          N/A
# 4999      N/A         N/A  26th Apr 96          N/A
#
# [5000 rows x 15 columns]
# done!

# %%
df6 = scrape(urlhead, urltail, 26, 31, file_n = 6)
# Out:
# Page: 26
# Page: 27
# Page: 28
# Page: 29
# Page: 30
# 5000
#                                                   Title Platform  \
# 0                                    Bakuretsu Hunter R      SAT
# 1                     Bakuretsu Hunter: Mahjong Special       PS
# 2     Bakuretsu Hunter: Sorezore no Omoi...Nowaan Ch...       PS
# 3                             Bakuretsu Muteki Bangai-O      N64
# 4                                      Bakuretsu Soccer       PS
# ...                                                 ...      ...
# 4995                               Donkey Kong Jr. Math       VC
# 4996                               Donkey Kong Jr. Math     WiiU
# 4997                                 Donkey Kong Junior     7800
# 4998                              Donkey Konga 1+2 Pack       GC
# 4999  Donkey Konga 3: Tabe-houdai! Haru Mogitate 50 ...       GC
#
#          Publisher           Developer VGC_Score Critic_Score User_Score  \
# 0     King Records        King Records       N/A          N/A        N/A
# 1        Banpresto           Banpresto       N/A          N/A        N/A
# 2        Banpresto           Banpresto       N/A          N/A        N/A
# 3              ESP  Treasure Co., Ltd.       N/A          N/A        N/A
# 4            Tecmo               Tecmo       N/A          N/A        N/A
# ...            ...                 ...       ...          ...        ...
# 4995      Nintendo            Nintendo       N/A          N/A        N/A
# 4996      Nintendo            Nintendo       N/A          N/A        N/A
# 4997         Atari            Nintendo       N/A          N/A        N/A
# 4998      Nintendo               Namco       N/A          N/A        N/A
# 4999      Nintendo               Namco       N/A          N/A        N/A
#
#      Total_Shipped Total_Sales NA_Sales EU_Sales JP_Sales Other_Sales  \
# 0              N/A         N/A      N/A      N/A      N/A         N/A
# 1              N/A         N/A      N/A      N/A      N/A         N/A
# 2              N/A         N/A      N/A      N/A      N/A         N/A
# 3              N/A         N/A      N/A      N/A      N/A         N/A
# 4              N/A         N/A      N/A      N/A      N/A         N/A
# ...            ...         ...      ...      ...      ...         ...
# 4995           N/A         N/A      N/A      N/A      N/A         N/A
# 4996           N/A         N/A      N/A      N/A      N/A         N/A
# 4997           N/A         N/A      N/A      N/A      N/A         N/A
# 4998           N/A         N/A      N/A      N/A      N/A         N/A
# 4999           N/A         N/A      N/A      N/A      N/A         N/A
#
#           Release Last_Update
# 0     08th Aug 97         N/A
# 1     25th Oct 96         N/A
# 2     11th Apr 97         N/A
# 3     03rd Sep 99         N/A
# 4     25th Jul 02         N/A
# ...           ...         ...
# 4995  03rd Sep 07         N/A
# 4996  28th Aug 14         N/A
# 4997  01st Jan 88         N/A
# 4998  01st Jul 04         N/A
# 4999  17th Mar 05         N/A
#
# [5000 rows x 15 columns]
# done!

# %%
df7 = scrape(urlhead, urltail, 31, 36, file_n = 7)
# Out:
# Page: 31
# Page: 32
# Page: 33
# Page: 34
# Page: 35
# 5000
#                                                   Title Platform  \
# 0                                           Donkey Xote      PSN
# 1                                           Donkey Xote      PSP
# 2                                              DonPachi      SAT
# 3                                              DonPachi       PS
# 4                                              DonPachi      PSN
# ...                                                 ...      ...
# 4995                           HTR+ Slot Car Simulation       PC
# 4996                Hubert the Teddy Bear: Winter Games       WW
# 4997  Hudson Best Collection Vol. 1: Bomberman Colle...      GBA
# 4998  Hudson Best Collection Vol. 2: Lode Runner Col...      GBA
# 4999   Hudson Best Collection Vol. 3: Action Collection      GBA
#
#                    Publisher                 Developer VGC_Score Critic_Score  \
# 0                Virgin Play               Virgin Play       N/A          N/A
# 1                Virgin Play               Virgin Play       N/A          N/A
# 2                      Atlus  Nihon Falcom Corporation       N/A          N/A
# 3                        SPS                      Cave       N/A          N/A
# 4        Hamster Corporation                      Cave       N/A          N/A
# ...                      ...                       ...       ...          ...
# 4995  Libredia Entertainment        QUByte Interactive       N/A          N/A
# 4996     Teyon Entertainment       Teyon Entertainment       N/A          N/A
# 4997             Hudson Soft               Hudson Soft       N/A          N/A
# 4998             Hudson Soft                    Hudson       N/A          N/A
# 4999             Hudson Soft                    Hudson       N/A          N/A
#
#      User_Score Total_Shipped Total_Sales NA_Sales EU_Sales JP_Sales  \
# 0           N/A           N/A         N/A      N/A      N/A      N/A
# 1           N/A           N/A         N/A      N/A      N/A      N/A
# 2           N/A           N/A         N/A      N/A      N/A      N/A
# 3           N/A           N/A         N/A      N/A      N/A      N/A
# 4           N/A           N/A         N/A      N/A      N/A      N/A
# ...         ...           ...         ...      ...      ...      ...
# 4995        N/A           N/A         N/A      N/A      N/A      N/A
# 4996        N/A           N/A         N/A      N/A      N/A      N/A
# 4997        N/A           N/A         N/A      N/A      N/A      N/A
# 4998        N/A           N/A         N/A      N/A      N/A      N/A
# 4999        N/A           N/A         N/A      N/A      N/A      N/A
#
#      Other_Sales      Release  Last_Update
# 0            N/A  02nd Jul 09          N/A
# 1            N/A  02nd Jul 09          N/A
# 2            N/A  26th Apr 96          N/A
# 3            N/A  18th Oct 96          N/A
# 4            N/A  12th May 10          N/A
# ...          ...          ...          ...
# 4995         N/A  29th May 14  11th Aug 18
# 4996         N/A  08th Feb 10          N/A
# 4997         N/A  22nd Dec 05          N/A
# 4998         N/A  22nd Dec 05          N/A
# 4999         N/A  22nd Dec 05          N/A
#
# [5000 rows x 15 columns]
# done!

# %%
df8 = scrape(urlhead, urltail, 36, 41, file_n = 8)
# Out:
# Page: 36
# Page: 37
# Page: 38
# Page: 39
# Page: 40
# 5000
#                                                   Title Platform  \
# 0     Hudson Best Collection Vol. 4: Nazotoki Collec...      GBA
# 1     Hudson Best Collection Vol. 5: Shooting Collec...      GBA
# 2     Hudson Best Collection Vol. 6: Bouken Jima Col...      GBA
# 3                                           Hudson Hawk       GB
# 4                                           Hudson Hawk      NES
# ...                                                 ...      ...
# 4995                               Nainai no Kiyotantei       PS
# 4996                 Nakadashi Haramase Shinyaku Chousa       PC
# 4997                                       Nakadasi Oni       PC
# 4998                          Nakajima Miyuki: Namiromu       PS
# 4999  Nakamura Sumiko Tettei Shidou: Shin TOEIC Test...       DS
#
#            Publisher       Developer VGC_Score Critic_Score User_Score  \
# 0        Hudson Soft          Hudson       N/A          N/A        N/A
# 1        Hudson Soft          Hudson       N/A          N/A        N/A
# 2        Hudson Soft          Hudson       N/A          N/A        N/A
# 3     Sony Imagesoft           Ocean       N/A          N/A        N/A
# 4     Sony Imagesoft           Ocean       N/A          N/A        N/A
# ...              ...             ...       ...          ...        ...
# 4995           Namco           Namco       N/A          N/A        N/A
# 4996         Unknown  softhouse-seal       N/A          N/A        N/A
# 4997         Unknown  softhouse-seal       N/A          N/A        N/A
# 4998         Oracion         Unknown       N/A          N/A        N/A
# 4999  Rocket Company  Rocket Company       N/A          N/A        N/A
#
#      Total_Shipped Total_Sales NA_Sales EU_Sales JP_Sales Other_Sales  \
# 0              N/A         N/A      N/A      N/A      N/A         N/A
# 1              N/A         N/A      N/A      N/A      N/A         N/A
# 2              N/A         N/A      N/A      N/A      N/A         N/A
# 3              N/A         N/A      N/A      N/A      N/A         N/A
# 4              N/A         N/A      N/A      N/A      N/A         N/A
# ...            ...         ...      ...      ...      ...         ...
# 4995           N/A         N/A      N/A      N/A      N/A         N/A
# 4996           N/A         N/A      N/A      N/A      N/A         N/A
# 4997           N/A         N/A      N/A      N/A      N/A         N/A
# 4998           N/A         N/A      N/A      N/A      N/A         N/A
# 4999           N/A         N/A      N/A      N/A      N/A         N/A
#
#           Release Last_Update
# 0     22nd Dec 05         N/A
# 1     19th Jan 06         N/A
# 2     19th Jan 06         N/A
# 3     01st Dec 91         N/A
# 4     01st Feb 92         N/A
# ...           ...         ...
# 4995  22nd Dec 99         N/A
# 4996  26th Aug 11         N/A
# 4997  26th Feb 10         N/A
# 4998  15th Oct 98         N/A
# 4999  02nd Oct 08         N/A
#
# [5000 rows x 15 columns]
# done!

# %%
df9 = scrape(urlhead, urltail, 41, 46, file_n = 9)
# Out:
# Page: 41
# Page: 42
# Page: 43
# Page: 44
# Page: 45
# 5000
#                                                   Title Platform   Publisher  \
# 0     Nakamura Tooru Kanshuu: Indo Shiki Keisan Dril...       DS      GungHo
# 1                Nakashima Tetsunari no Othello Seminar       XB     Success
# 2        Nakayoshi Cooking Series 1: Oishii Cake Okusan       GB         MTO
# 3         Nakayoshi Cooking Series 2: Oishii Pan Okusan       GB         MTO
# 4                           Nakayoshi Mahjong Kapurichi      GBA      Konami
# ...                                                 ...      ...         ...
# 4995  Sea Animal Games for Toddlers and Kids with Ji...     XOne     Ubisoft
# 4996  Sea Animal Games for Toddlers and Kids with Ji...      And     Ubisoft
# 4997  Sea Animal Games for Toddlers and Kids with Ji...       DS     Ubisoft
# 4998  Sea Animal Games for Toddlers and Kids with Ji...    Linux     Ubisoft
# 4999                                         Sea Battle       GB  Infogrames
#
#          Developer VGC_Score Critic_Score User_Score Total_Shipped  \
# 0           GungHo       N/A          N/A        N/A           N/A
# 1          Success       N/A          N/A        N/A           N/A
# 2              MTO       N/A          N/A        N/A           N/A
# 3              MTO       N/A          N/A        N/A           N/A
# 4           Konami       N/A          N/A        N/A           N/A
# ...            ...       ...          ...        ...           ...
# 4995       Unknown       N/A          N/A        N/A           N/A
# 4996       Unknown       N/A          N/A        N/A           N/A
# 4997       Unknown       N/A          N/A        N/A           N/A
# 4998       Unknown       N/A          N/A        N/A           N/A
# 4999  Bit Managers       N/A          N/A        N/A           N/A
#
#      Total_Sales NA_Sales EU_Sales JP_Sales Other_Sales      Release  \
# 0            N/A      N/A      N/A      N/A         N/A  28th Feb 08
# 1            N/A      N/A      N/A      N/A         N/A  13th Jun 02
# 2            N/A      N/A      N/A      N/A         N/A  15th Dec 00
# 3            N/A      N/A      N/A      N/A         N/A  20th Apr 01
# 4            N/A      N/A      N/A      N/A         N/A  25th Oct 01
# ...          ...      ...      ...      ...         ...          ...
# 4995         N/A      N/A      N/A      N/A         N/A  01st Dec 13
# 4996         N/A      N/A      N/A      N/A         N/A  01st Sep 13
# 4997         N/A      N/A      N/A      N/A         N/A  01st Jul 14
# 4998         N/A      N/A      N/A      N/A         N/A  01st Jul 14
# 4999         N/A      N/A      N/A      N/A         N/A  01st Jan 98
#
#      Last_Update
# 0            N/A
# 1            N/A
# 2            N/A
# 3            N/A
# 4            N/A
# ...          ...
# 4995         N/A
# 4996         N/A
# 4997         N/A
# 4998         N/A
# 4999         N/A
#
# [5000 rows x 15 columns]
# done!

# %%
df10 = scrape(urlhead, urltail, 46, 51, file_n = 10)
# Out:
# Page: 46
# Page: 47
# Page: 48
# Page: 49
# Page: 50
# 5000
#                                                  Title Platform  \
# 0                                           Sea Battle     2600
# 1                                            Sea Blast      XBL
# 2                                           Sea Dragon     2600
# 3                                           Sea Dragon       PC
# 4                                             Sea Hawk     2600
# ...                                                ...      ...
# 4995                                 The Sword of Hope       GB
# 4996                                 The Sword of Hope      3DS
# 4997                            The Tale of Despereaux       PC
# 4998  The Tales of Bearsworth Manor: Chaotic Conflicts       WW
# 4999     The Tales of Bearsworth Manor: Puzzling Pages       WW
#
#                 Publisher                Developer VGC_Score Critic_Score  \
# 0                 Unknown                     INTV       N/A          N/A
# 1               Microsoft                 SeaBlast       N/A          N/A
# 2                 Unknown  Adventure International       N/A          N/A
# 3                 Unknown  Adventure International       N/A          N/A
# 4                 Unknown                   Froggo       N/A          N/A
# ...                   ...                      ...       ...          ...
# 4995                Seika                    Kemco       N/A          N/A
# 4996                Kemco                    Kemco       N/A          N/A
# 4997  Brash Entertainment    Sensory Sweep Studios       N/A          N/A
# 4998          Square Enix              Square Enix       N/A          N/A
# 4999          Square Enix              Square Enix       N/A          N/A
#
#      User_Score Total_Shipped Total_Sales NA_Sales EU_Sales JP_Sales  \
# 0           N/A           N/A         N/A      N/A      N/A      N/A
# 1           N/A           N/A         N/A      N/A      N/A      N/A
# 2           N/A           N/A         N/A      N/A      N/A      N/A
# 3           N/A           N/A         N/A      N/A      N/A      N/A
# 4           N/A           N/A         N/A      N/A      N/A      N/A
# ...         ...           ...         ...      ...      ...      ...
# 4995        N/A           N/A         N/A      N/A      N/A      N/A
# 4996        N/A           N/A         N/A      N/A      N/A      N/A
# 4997        N/A           N/A         N/A      N/A      N/A      N/A
# 4998        N/A           N/A         N/A      N/A      N/A      N/A
# 4999        N/A           N/A         N/A      N/A      N/A      N/A
#
#      Other_Sales      Release Last_Update
# 0            N/A  01st Jan 00         N/A
# 1            N/A  14th Dec 08         N/A
# 2            N/A          N/A         N/A
# 3            N/A  01st Jan 83         N/A
# 4            N/A  01st Jan 82         N/A
# ...          ...          ...         ...
# 4995         N/A  01st Jun 91         N/A
# 4996         N/A  07th Dec 11         N/A
# 4997         N/A  16th Dec 08         N/A
# 4998         N/A  21st Jun 10         N/A
# 4999         N/A  21st Jun 10         N/A
#
# [5000 rows x 15 columns]
# done!

# %%
df11 = scrape(urlhead, urltail, 51, 56, file_n = 11)
# Out:
# Page: 51
# Page: 52
# Page: 53
# Page: 54
# Page: 55
# 5000
#                                       Title Platform  \
# 0                       The Talos Principle    Linux
# 1                       The Talos Principle      OSX
# 2                       The Talos Principle      And
# 3     The Tekkyu Fight! Great Battle Gaiden       GB
# 4                   The TEMPURA of the DEAD      XBL
# ...                                     ...      ...
# 4995                        Death Stranding      PS4
# 4996                        Death Stranding       PC
# 4997                         Death's Gambit      PS4
# 4998                              Deathloop       PC
# 4999                              Deathloop      PS5
#
#                            Publisher           Developer VGC_Score  \
# 0                   Devolver Digital             Croteam       N/A
# 1                   Devolver Digital             Croteam       N/A
# 2                   Devolver Digital             Croteam       N/A
# 3                          Banpresto           Banpresto       N/A
# 4                          Microsoft  JPN 8bits fanatics       N/A
# ...                              ...                 ...       ...
# 4995  Sony Interactive Entertainment  Kojima Productions       4.0
# 4996                       505 Games  Kojima Productions       N/A
# 4997                  Skybound Games        White Rabbit       N/A
# 4998              Bethesda Softworks      Arkane Studios       N/A
# 4999              Bethesda Softworks      Arkane Studios       N/A
#
#      Critic_Score User_Score Total_Shipped Total_Sales NA_Sales EU_Sales  \
# 0             N/A        N/A           N/A         N/A      N/A      N/A
# 1             N/A        N/A           N/A         N/A      N/A      N/A
# 2             N/A        N/A           N/A         N/A      N/A      N/A
# 3             N/A        N/A           N/A         N/A      N/A      N/A
# 4             N/A        N/A           N/A         N/A      N/A      N/A
# ...           ...        ...           ...         ...      ...      ...
# 4995          N/A        N/A           N/A         N/A      N/A      N/A
# 4996          N/A        N/A           N/A         N/A      N/A      N/A
# 4997          N/A        N/A           N/A         N/A      N/A      N/A
# 4998          N/A        N/A           N/A         N/A      N/A      N/A
# 4999          N/A        N/A           N/A         N/A      N/A      N/A
#
#      JP_Sales Other_Sales      Release  Last_Update
# 0         N/A         N/A  11th Dec 14          N/A
# 1         N/A         N/A  11th Dec 14          N/A
# 2         N/A         N/A  28th May 15          N/A
# 3         N/A         N/A  30th Jul 93          N/A
# 4         N/A         N/A  09th Nov 10          N/A
# ...       ...         ...          ...          ...
# 4995      N/A         N/A  08th Nov 19  10th Apr 20
# 4996      N/A         N/A  14th Jul 20  17th Dec 19
# 4997      N/A         N/A  05th Mar 19  11th Sep 18
# 4998      N/A         N/A  01st Dec 20  09th Jun 19
# 4999      N/A         N/A  01st Jul 21  13th Jun 20
#
# [5000 rows x 15 columns]
# done!

# %%
df12 = scrape(urlhead, urltail, 56, 61, file_n = 12)
# Out:
# Page: 56
# Page: 57
# Page: 58
# Page: 59
# Page: 60
# 4398
#                                         Title Platform  \
# 0                           Deathtrap Dungeon       PC
# 1                              Decay of Logos     XOne
# 2                              Decay of Logos      PS4
# 3                              Decay of Logos       PC
# 4                              Decay of Logos       NS
# ...                                       ...      ...
# 4393       Zombieland: Double Tap - Road Trip       PC
# 4394                                Zombillie       NS
# 4395  Zone of the Enders: The 2nd Runner MARS       PC
# 4396   Zoo Tycoon: Ultimate Animal Collection     XOne
# 4397   Zoo Tycoon: Ultimate Animal Collection       PC
#
#                        Publisher                   Developer VGC_Score  \
# 0                        Unknown        Asylum Entertainment       N/A
# 1              Rising Star Games           Amplify Creations       N/A
# 2              Rising Star Games           Amplify Creations       N/A
# 3              Rising Star Games           Amplify Creations       N/A
# 4              Rising Star Games           Amplify Creations       N/A
# ...                          ...                         ...       ...
# 4393      GameMill Entertainment       High Voltage Software       N/A
# 4394  Forever Entertainment S.A.  Forever Entertainment S.A.       N/A
# 4395                      Konami                     Cygames       N/A
# 4396           Microsoft Studios       Frontier Developments       N/A
# 4397                  THQ Nordic       Frontier Developments       N/A
#
#      Critic_Score User_Score Total_Shipped Total_Sales NA_Sales EU_Sales  \
# 0             N/A        N/A           N/A         N/A      N/A      N/A
# 1             N/A        N/A           N/A         N/A      N/A      N/A
# 2             N/A        N/A           N/A         N/A      N/A      N/A
# 3             N/A        N/A           N/A         N/A      N/A      N/A
# 4             N/A        N/A           N/A         N/A      N/A      N/A
# ...           ...        ...           ...         ...      ...      ...
# 4393          N/A        N/A           N/A         N/A      N/A      N/A
# 4394          N/A        N/A           N/A         N/A      N/A      N/A
# 4395          N/A        N/A           N/A         N/A      N/A      N/A
# 4396          N/A        N/A           N/A         N/A      N/A      N/A
# 4397          N/A        N/A           N/A         N/A      N/A      N/A
#
#      JP_Sales Other_Sales      Release  Last_Update
# 0         N/A         N/A          N/A  28th Jun 18
# 1         N/A         N/A  30th Aug 19  10th Aug 19
# 2         N/A         N/A  27th Aug 19  10th Aug 19
# 3         N/A         N/A  30th Aug 19  10th Aug 19
# 4         N/A         N/A  29th Aug 19  10th Aug 19
# ...       ...         ...          ...          ...
# 4393      N/A         N/A  15th Oct 19  25th Sep 20
# 4394      N/A         N/A  29th Mar 18  26th Mar 18
# 4395      N/A         N/A  06th Sep 18  26th Sep 18
# 4396      N/A         N/A  31st Oct 17  26th Sep 18
# 4397      N/A         N/A  14th Sep 18  19th Nov 18
#
# [4398 rows x 15 columns]
# done!

# %% [markdown]
# ---
# # Joining the datasets into a single dataset

# %%
data = pd.DataFrame()

dfs = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12]

for df in dfs:
    
    data = pd.concat([data, df], ignore_index = True)

# %% [markdown]
# We know there were 59398 data points in total (5000 x 11 + 4398). Let's make sure the merged dataframe has this many rows.

# %%
data.shape[0]
# Out:
# 59398

# %% [markdown]
# Save the dataset into a `.csv` file

# %%
data.head()
# Out:
#               Title Platform       Publisher  \
# 0            Tetris   Series         Unknown
# 1       Super Mario   Series        Nintendo
# 2           Pokemon   Series        Nintendo
# 3  Grand Theft Auto   Series  Rockstar Games
# 4              FIFA   Series       EA Sports
#
#                                Developer  VGC_Score  Critic_Score  User_Score  \
# 0                        Alexey Pajitnov        NaN           NaN         NaN
# 1                               Nintendo        NaN           NaN         NaN
# 2                             Game Freak        NaN           NaN         NaN
# 3                         Rockstar North        NaN           NaN         NaN
# 4  Extended Play Productions (1991-1997)        NaN           NaN         NaN
#
#   Total_Shipped Total_Sales NA_Sales EU_Sales JP_Sales Other_Sales  \
# 0       496.00m         NaN      NaN      NaN      NaN         NaN
# 1       372.86m         NaN      NaN      NaN      NaN         NaN
# 2       369.88m         NaN      NaN      NaN      NaN         NaN
# 3       335.00m         NaN      NaN      NaN      NaN         NaN
# 4       325.00m         NaN      NaN      NaN      NaN         NaN
#
#        Release  Last_Update
# 0  06th Jun 84  27th Feb 20
# 1  20th Jul 83  20th Feb 20
# 2  28th Sep 98  03rd Feb 20
# 3  27th Mar 98  03rd Feb 20
# 4  15th Dec 93  03rd Feb 20

# %%
data.to_csv("vgsales.csv", sep=",", encoding='utf-8')
